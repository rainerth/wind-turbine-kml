# %%
"""
Windpark Bösingen - 3D-Visualisierung für Google Earth Pro und Cesium.

Conda-Umgebung aktivieren:
    conda activate py311

Abhängigkeiten installieren:
    pip install -r requirements.txt

Cesium-Konfiguration (.env-Datei):
    CESIUM_ION_TOKEN=<dein-upload-token>
    CESIUM_ION_TOKEN_READONLY=<dein-read-only-token>

WICHTIG: Die Zellen bauen nacheinander EIN gemeinsames KML-Dokument auf und
müssen deshalb von oben nach unten ausgeführt werden. Wird eine der
Aufbau-Zellen (4-10) erneut ausgeführt, landen deren Inhalte doppelt im
Dokument - dann bitte ab dieser Zelle neu starten.
"""
import os
import math
import glob
import json
import zipfile
from xml.etree import ElementTree as ET

import numpy as np
import pandas as pd
import geopandas as gpd
import simplekml
import trimesh
from dotenv import load_dotenv
# https://simplekml.readthedocs.io/en/latest/index.html

import collada_wt
from kml2track import kml_extract_launch_phase
from kml2track import igc_extract_launch_phase
# Ungefilterte Varianten: liefern den ersten Fix am Boden für die Bodenreferenz.
from kml2track import kml_extract_altitude_section
from kml2track import igc_extract_altitude_section

# ============================================================================
# KONFIGURATION
# ============================================================================
CONFIG = {
    # Sicherheitsabstände
    'safety_distance_meter': 50,      # Mindestabstand in Metern
    'safety_distance_factor': 1.0,    # Faktor für Rotordurchmesser
    'safety_distance_top': 100,       # Abstand zur Turbinenspitze in Metern

    # Rotor-Ausrichtung (0°=Nord, 90°=Ost, 180°=Süd, 270°=West)
    'rotor_orientation': 225,         # Südwest - optimal für BaWü

    # Verzeichnisstruktur
    'directory_nesting': True,        # Unterordner in KML (einige Apps unterstützen nur eine Ebene)

    # Auflösung der Kreispolygone (Zylinder, Schutzzonen). Die Segmentzahl
    # richtet sich nach dem Radius, damit die Sehne zwischen zwei Stützpunkten
    # kurz bleibt: Google Earth zieht dazwischen eine Gerade, und zu lange
    # Sehnen lassen geländebezogene Geometrie über Tälern in der Luft hängen.
    'circle_max_chord_m': 10,      # angestrebte Sehnenlänge
    'circle_min_segments': 36,     # untere Schranke für sehr kleine Kreise
    'circle_max_segments': 360,    # obere Schranke (wie bisher fest verdrahtet)

    # Geländefolgende Flächen (Platzrunde, An-/Abflugkorridore). Deren Höhen
    # sind Meter ÜBER GRUND (relativeToGround). Google Earth legt nur die
    # Stützpunkte aufs Gelände, dazwischen liegen Geraden - deshalb muss jede
    # Kante unterteilt werden, sonst schwebt die Fläche über Senken.
    'terrain_max_chord_m': 60,     # max. Kantenlänge einer Gitterzelle
    'terrain_max_cells': 800,      # Deckel je Fläche, damit die KML klein bleibt

    # Pfade
    'models_dir': 'models',
    'output_dir': './output',
    'output_kml': './output/WEA-boesingen.kml',
    'output_kmz': './output/WEA-boesingen.kmz',
    'wka_shapefile': 'areas/RVSBH_Teilplan_WKA/pg_8174_windenergie.shp',
    'ffpv_shapefile': ('areas/RVSBH_Teilplan_FFPV/RVSBH_Teilplan_FFPV Stand n2_Bet/'
                       'RVSBH_Teilplan_FFPV_Stand_n2_Bet.shp'),

    # Koordinatengrenzen für Track-Validierung (Bösingen-Region)
    'area_lat_min': 48.1,
    'area_lat_max': 48.3,
    'area_lon_min': 8.4,
    'area_lon_max': 8.6,

    # Flugplatz Bösingen als (Longitude, Latitude)
    'airfield_boesingen': (8.534621455251553, 48.227697118500274),
}

ROTOR_ORIENTATION = CONFIG['rotor_orientation']
DIRECTORY_NESTING = CONFIG['directory_nesting']

# Landebahn Bösingen als (Longitude, Latitude, Altitude), geschlossener Ring.
# Wird von der KML-, der Web-KML- und der CZML-Ausgabe gemeinsam genutzt.
LANDEBAHN_COORDS = [
    (8.531799515709411, 48.22788047237495, 0),
    (8.531791237373254, 48.22746570381057, 0),
    (8.537614083339131, 48.22746248646123, 0),
    (8.537607267242425, 48.22789309924998, 0),
    (8.531799515709411, 48.22788047237495, 0),
]

os.makedirs(CONFIG['output_dir'], exist_ok=True)

# KML-Dokument initialisieren
kml = simplekml.Kml()
# Wurzel MUSS ein Document sein: Shared Styles (Style mit id, referenziert per
# styleUrl) sind laut KML-Spezifikation nur unter <Document> gültig. Mit einem
# Folder als Wurzel lädt Google Earth Pro die Datei zwar, Google Earth Web
# meldet dagegen für jedes Element "verweist auf den nicht vorhandenen Stil".
kml.document = simplekml.Document(name="Windpark Bösingen")

print("Konfiguration geladen:")
print(f"  - Rotor-Ausrichtung: {ROTOR_ORIENTATION}° (Südwest)")
print(f"  - Sicherheitsabstand: {CONFIG['safety_distance_meter']}m "
      f"+ {CONFIG['safety_distance_factor']}x Rotordurchmesser")
print(f"  - Kreisauflösung: max. {CONFIG['circle_max_chord_m']}m Sehnenlänge "
      f"({CONFIG['circle_min_segments']}-{CONFIG['circle_max_segments']} Segmente)")
print(f"  - Ausgabeverzeichnis: {CONFIG['output_dir']}")

# %%
# ============================================================================
# HILFSFUNKTIONEN
# ============================================================================
#
# REGEL FÜR ALLE HÖHEN IN GOOGLE EARTH
# ------------------------------------
# 1. Alles mit relativeToGround zeichnen, Höhen in Metern ÜBER GRUND.
#    Google Earths Geländemodell stimmt nicht mit echtem MSL überein. Absolute
#    Höhen treffen deshalb auf ein Gelände, das anders liegt als angenommen,
#    und die Geometrie schwebt (oder versinkt) - unabhängig davon, wie korrekt
#    der MSL-Wert der Quelle ist. Dieselbe Erkenntnis steht in
#    ~/prj/thermikdash/tools/incident_kml.py ("GE-Terrain != echtes MSL sonst")
#    und im Vorfall-KMZ 2026-08-08, das durchgängig relativeToGround verwendet.
# 2. Die Bodenreferenz aus den Daten selbst nehmen, nicht als Konstante
#    annehmen: den Startpunkt am Boden (erster Fix, erster CSV-Punkt). Jeder
#    Logger hat einen eigenen Offset - für denselben Startplatz wurden hier
#    692-697 m gemessen.
# 3. Nur echte Bodenflächen (Landebahn, Schutzzonen) mit clampToGround, und
#    dort immer tessellate=1.
# 4. Bei relativeToGround folgt die Geometrie dem Gelände NUR an den
#    Stützpunkten. Jede lange Kante vorher unterteilen (densify_path,
#    terrain_grid_cells), sonst überspannt sie Senken.

# Meter pro Breitengrad (Mittelwert). Für Längengrade zusätzlich cos(Breite).
METER_PER_DEG_LAT = 111139


def degrees_per_meter(lat):
    """Umrechnungsfaktoren Meter -> Grad an einer Breite.

    Returns:
        (deg_pro_meter_lon, deg_pro_meter_lat)
    """
    deg_lat = 1 / METER_PER_DEG_LAT
    deg_lon = deg_lat / math.cos(math.radians(lat))
    return deg_lon, deg_lat


# Bodengebundene Polygone brauchen tessellate=1: nur dann unterteilt Google
# Earth die Kanten und legt sie auf das Gelände. Ohne Tessellierung ist jede
# Kante eine Gerade zwischen zwei Stützpunkten und hängt über Tälern in der
# Luft. Wirkt laut KML-Spezifikation ausschließlich bei clampToGround.
CLAMPED = dict(altitudemode=simplekml.AltitudeMode.clamptoground, tessellate=1)


def close_ring(coords):
    """Schließt einen Koordinatenring, falls nötig.

    Die KML-Spezifikation verlangt für LinearRing, dass der letzte Punkt dem
    ersten entspricht. Google Earth verzeiht offene Ringe, andere Betrachter
    nicht zwingend.
    """
    if coords and coords[0] != coords[-1]:
        return list(coords) + [coords[0]]
    return list(coords)


def circle_segments_for(radius_m):
    """Segmentzahl, damit die Sehnenlänge unter circle_max_chord_m bleibt.

    Google Earth verbindet zwei Stützpunkte geradlinig. Bei clampToGround und
    relativeToGround folgt die Geometrie dem Gelände deshalb nur an den
    Stützpunkten - eine zu lange Sehne überspannt Täler und die Fläche hängt
    sichtbar in der Luft. Große Kreise brauchen daher mehr Punkte als kleine;
    eine feste Segmentzahl für alle Radien ist falsch.
    """
    needed = math.ceil(2 * math.pi * radius_m / CONFIG['circle_max_chord_m'])
    return max(CONFIG['circle_min_segments'],
               min(CONFIG['circle_max_segments'], needed))


def circle_coords(center, radius_m, height=0, segments=None):
    """Koordinatenring eines Kreises um center=(lon, lat).

    Der Ring wird geschlossen (letzter Punkt = erster Punkt), wie es die
    KML-Spezifikation für LinearRing verlangt.
    """
    if segments is None:
        segments = circle_segments_for(radius_m)
    lon, lat = center
    deg_lon, deg_lat = degrees_per_meter(lat)
    radius_deg_lat = radius_m * deg_lat
    radius_deg_lon = radius_m * deg_lon

    coords = []
    for i in range(segments):
        theta = 2 * math.pi * i / segments
        coords.append((lon + radius_deg_lon * math.cos(theta),
                       lat + radius_deg_lat * math.sin(theta),
                       height))
    return close_ring(coords)


def create_kml_cylinder(kmlfolder, cyl_center, cyl_diameter, cyl_height,
                        cyl_color=simplekml.Color.green, cyl_name='cylinder',
                        cyl_visibility=1, segments=None):
    """Erstellt einen Zylinder als KML-Polygon (für Turbinen, Sicherheitszonen etc.)"""
    coords = circle_coords(cyl_center, cyl_diameter / 2, cyl_height, segments)

    pol = kmlfolder.newpolygon(
        name=cyl_name,
        outerboundaryis=coords,
        altitudemode=simplekml.AltitudeMode.relativetoground,
        extrude=1,
        visibility=cyl_visibility
    )
    pol.style.linestyle.width = 1
    pol.style.linestyle.color = cyl_color
    pol.style.polystyle.color = simplekml.Color.changealphaint(200, cyl_color)
    pol.style.polystyle.outline = 1
    pol.style.polystyle.fill = 1
    return pol


def _corridor_quad(start_lat, start_lon, start_altitude, direction, length, slope, width):
    """Grundfläche eines An-/Abflugkorridors als vier (lon, lat, alt)-Punkte.

    Gemeinsame Geometrie von create_kml_slope() und create_kml_cube().

    Einheiten: length und width in KILOMETERN, start_altitude in Metern,
    direction und slope in Grad.
    """
    direction_rad = math.radians(direction)
    slope_rad = math.radians(slope)

    height = length * math.sin(slope_rad)
    distance = length * math.cos(slope_rad)

    # Startpunkt um eine halbe Breite versetzen, damit der Korridor mittig liegt.
    half_width = width / 2
    start_lat -= half_width * math.cos(direction_rad + math.pi / 2) / 111.32
    start_lon -= half_width * math.sin(direction_rad + math.pi / 2) / (111.32 * math.cos(math.radians(start_lat)))

    end_lat = start_lat + distance * math.cos(direction_rad) / 111.32
    end_lon = start_lon + distance * math.sin(direction_rad) / (111.32 * math.cos(math.radians(start_lat)))
    end_altitude = start_altitude + height * 1000

    width_lat1 = start_lat + width * math.cos(direction_rad + math.pi / 2) / 111.32
    width_lon1 = start_lon + width * math.sin(direction_rad + math.pi / 2) / (111.32 * math.cos(math.radians(start_lat)))
    width_lat2 = end_lat + width * math.cos(direction_rad + math.pi / 2) / 111.32
    width_lon2 = end_lon + width * math.sin(direction_rad + math.pi / 2) / (111.32 * math.cos(math.radians(end_lat)))

    return [
        (start_lon, start_lat, start_altitude),
        (end_lon, end_lat, end_altitude),
        (width_lon2, width_lat2, end_altitude),
        (width_lon1, width_lat1, start_altitude),
    ]


def meters_between(a, b):
    """Horizontaler Abstand zweier (lon, lat, ...)-Punkte in Metern."""
    lon1, lat1 = a[0], a[1]
    lon2, lat2 = b[0], b[1]
    deg_lon, deg_lat = degrees_per_meter((lat1 + lat2) / 2)
    dx = (lon2 - lon1) / deg_lon
    dy = (lat2 - lat1) / deg_lat
    return math.hypot(dx, dy)


def densify_path(coords, max_chord_m=None):
    """Fügt Zwischenpunkte ein, bis keine Kante länger als max_chord_m ist.

    Notwendig für relativeToGround: Google Earth legt nur die Stützpunkte auf
    das Gelände und zieht dazwischen Geraden. Eine 3 km lange Kante mit zwei
    Stützpunkten hängt deshalb über jeder Senke in der Luft - genau der Effekt,
    der die Anflugkorridore und die Platzrunde schweben ließ.
    """
    if max_chord_m is None:
        max_chord_m = CONFIG['terrain_max_chord_m']

    dense = []
    for a, b in zip(coords, coords[1:]):
        dense.append(tuple(a))
        steps = max(1, math.ceil(meters_between(a, b) / max_chord_m))
        for s in range(1, steps):
            t = s / steps
            dense.append(tuple(a[i] + (b[i] - a[i]) * t for i in range(3)))
    if coords:
        dense.append(tuple(coords[-1]))
    return dense


def _lerp_point(a, b, t):
    return tuple(a[i] + (b[i] - a[i]) * t for i in range(3))


def terrain_grid_cells(quad, max_chord_m=None):
    """Zerlegt ein Viereck in ein Gitter geländefolgender Vierecke.

    quad ist die Ausgabe von _corridor_quad(): [start_links, ende_links,
    ende_rechts, start_rechts]. Jede Zelle ist klein genug, dass ihre Ecken
    dem Gelände folgen; eine einzige große Fläche wäre dagegen eben und würde
    über Tälern schweben.

    Yields:
        Listen aus vier (lon, lat, alt)-Punkten.
    """
    if max_chord_m is None:
        max_chord_m = CONFIG['terrain_max_chord_m']

    p_start_l, p_end_l, p_end_r, p_start_r = quad

    length_m = meters_between(p_start_l, p_end_l)
    width_m = meters_between(p_start_l, p_start_r)

    n_long = max(1, math.ceil(length_m / max_chord_m))
    n_cross = max(1, math.ceil(width_m / max_chord_m))

    # Gitter deckeln: sehr große Flächen (Abflugkorridor: 5 x 2 km) ergäben
    # sonst Tausende Polygone. Beide Richtungen gleichmäßig ausdünnen.
    max_cells = CONFIG['terrain_max_cells']
    if n_long * n_cross > max_cells:
        scale = math.sqrt(max_cells / (n_long * n_cross))
        n_long = max(1, int(n_long * scale))
        n_cross = max(1, int(n_cross * scale))

    def at(u, v):
        """Bilineare Interpolation im Viereck: u laengs, v quer."""
        return _lerp_point(_lerp_point(p_start_l, p_end_l, u),
                           _lerp_point(p_start_r, p_end_r, u), v)

    for i in range(n_long):
        u0, u1 = i / n_long, (i + 1) / n_long
        for j in range(n_cross):
            v0, v1 = j / n_cross, (j + 1) / n_cross
            yield [at(u0, v0), at(u1, v0), at(u1, v1), at(u0, v1)]


def _add_terrain_surface(folder, quad, color, name, transparency,
                         outline_color=None, outline_width=2):
    """Legt ein Viereck als geländefolgende Fläche plus Umrandung ab.

    Alle Teilpolygone laufen mit relativeToGround: die Höhenangaben sind Meter
    ÜBER GRUND, nicht über NN. Absolute Höhen waren der Grund, warum die
    Korridore zu hoch standen - sie unterstellten eine Platzhöhe, die nicht der
    Geländehöhe von Google Earth entspricht.
    """
    fill = simplekml.Color.changealphaint(transparency, color)

    # Ein gemeinsames Style-Objekt für alle Gitterzellen: simplekml schreibt es
    # dann einmal ins Dokument statt einmal je Polygon. Ohne das wächst die KML
    # bei einigen hundert Zellen unnötig um ein Vielfaches.
    cell_style = simplekml.Style()
    cell_style.polystyle.color = fill
    cell_style.polystyle.outline = 0
    cell_style.linestyle.color = fill
    cell_style.linestyle.width = 0

    for cell in terrain_grid_cells(quad):
        pol = folder.newpolygon(name=name, outerboundaryis=close_ring(cell),
                                altitudemode=simplekml.AltitudeMode.relativetoground)
        pol.style = cell_style

    # Kontur separat, damit die Gitterkanten die Fläche nicht zerschneiden.
    border = folder.newlinestring(
        name=f"{name} (Rand)",
        coords=densify_path(close_ring(quad)),
        altitudemode=simplekml.AltitudeMode.relativetoground
    )
    border.style.linestyle.color = outline_color or color
    border.style.linestyle.width = outline_width
    return border


def create_kml_slope(kml_folder, start_lat, start_lon, start_altitude,
                     direction, length, slope, width,
                     color=simplekml.Color.yellow, name="slope"):
    """Erstellt eine geneigte, geländefolgende Fläche (An-/Abflugkorridore).

    start_altitude ist die Höhe ÜBER GRUND am Platz (Meter), nicht über NN.
    """
    transparency = 100
    quad = _corridor_quad(start_lat, start_lon, start_altitude,
                          direction, length, slope, width)

    folder = kml_folder.newfolder(name=name)
    _add_terrain_surface(folder, quad, color, name, transparency)
    return folder


def create_kml_cube(kml_folder, start_lat, start_lon, start_altitude,
                    direction, length, slope, width,
                    color=simplekml.Color.yellow, name="cube"):
    """Erstellt einen geländefolgenden Quader (Abflugbereich).

    start_altitude ist die Höhe ÜBER GRUND am Platz (Meter), nicht über NN.
    """
    cube_folder = kml_folder.newfolder(name='Abflugbereich')
    cube_folder.visibility = 0

    cube_height = 100
    transparency = 80

    lower = _corridor_quad(start_lat, start_lon, start_altitude,
                           direction, length, slope, width)
    upper = [(lon, lat, alt + cube_height) for lon, lat, alt in lower]

    _add_terrain_surface(cube_folder, lower, color, name, transparency)
    _add_terrain_surface(cube_folder, upper, color, name, transparency)

    # Seitenflächen: unten und oben derselbe Grundriss, deshalb genügt es,
    # die Kante längs zu verdichten und je Teilstück ein Wandstück zu setzen.
    fill = simplekml.Color.changealphaint(transparency, color)
    wall_style = simplekml.Style()
    wall_style.polystyle.color = fill
    wall_style.polystyle.outline = 0
    wall_style.linestyle.color = fill
    wall_style.linestyle.width = 0

    for i in range(4):
        edge = densify_path([lower[i], lower[(i + 1) % 4]])
        for p, q in zip(edge, edge[1:]):
            wall = [p, (p[0], p[1], p[2] + cube_height),
                    (q[0], q[1], q[2] + cube_height), q]
            pol = cube_folder.newpolygon(
                name=name, outerboundaryis=close_ring(wall),
                altitudemode=simplekml.AltitudeMode.relativetoground)
            pol.style = wall_style


def calculate_slope(speed_kmh, climb_rate_ms):
    """Berechnet den Steigungswinkel aus Geschwindigkeit und Steigrate"""
    speed_ms = speed_kmh * 1000 / 3600
    slope_rad = math.atan(climb_rate_ms / speed_ms)
    return math.degrees(slope_rad)


def create_kml_line(kml_folder, coordinates, flight_name, flight_url=None,
                    color=simplekml.Color.lightblue):
    """Erstellt eine Linie für Flugtracks.

    coordinates enthält Höhen ÜBER GRUND (siehe track_ground_reference und die
    Regel im Kopf dieser Zelle), deshalb relativeToGround.
    """
    ls = kml_folder.newlinestring(name=flight_name)
    ls.coords = coordinates
    ls.extrude = 0
    ls.altitudemode = simplekml.AltitudeMode.relativetoground
    ls.style.linestyle.width = 2
    ls.style.linestyle.color = color
    if flight_url:
        ls.description = f'<a href="{flight_url}">{flight_name}</a>'
    else:
        ls.description = flight_name
    ls.visibility = 1
    return ls


def compass_offset(distance, heading_rad):
    """Versatz (Ost, Nord) in Metern für eine Strecke entlang einer Kompasspeilung.

    Kompasskonvention: 0°=Nord, 90°=Ost, im Uhrzeigersinn.
    """
    return distance * math.sin(heading_rad), distance * math.cos(heading_rad)


def create_kml_turbine_simple(kmlfolder, center, height, diameter, name,
                              color_tower=simplekml.Color.white,
                              color_nacelle=simplekml.Color.lightgray,
                              color_rotor=simplekml.Color.white,
                              rotor_heading=225, visibility=1):
    """Erstellt eine vereinfachte WEA-Darstellung aus KML-Primitiven (für Google Earth Web).

    Die Rotorblätter stehen vertikal in einer Ebene senkrecht zur Gondel,
    mit dem Mittelpunkt (Nabe) an der Spitze der Gondel.

    Args:
        kmlfolder: KML-Ordner für die Geometrie
        center: (longitude, latitude) Tuple
        height: Nabenhöhe in Metern
        diameter: Rotordurchmesser in Metern
        name: Name der Turbine
        color_tower: Farbe des Turms
        color_nacelle: Farbe der Gondel
        color_rotor: Farbe der Rotorblätter
        rotor_heading: Ausrichtung der Gondel in Grad (0=Nord, Richtung in die der Rotor zeigt)
        visibility: Sichtbarkeit (0 oder 1)
    """
    lon, lat = center
    meter_to_deg_lon, meter_to_deg_lat = degrees_per_meter(lat)

    # --- Turm als schmaler Zylinder ---
    # Realistische Proportionen: Turm-Durchmesser ca. 2.5% des Rotordurchmessers
    tower_diameter = max(3, diameter * 0.025)
    tower_coords = circle_coords((lon, lat), tower_diameter / 2, height, segments=24)

    tower = kmlfolder.newpolygon(
        name=f"{name} Turm",
        outerboundaryis=tower_coords,
        altitudemode=simplekml.AltitudeMode.relativetoground,
        extrude=1,
        visibility=visibility
    )
    # Umriss aus: KML-Linienbreiten sind PIXEL und skalieren nicht mit der
    # Entfernung. Bei Extrusion zeichnet Google Earth den Umriss jeder der 24
    # Seitenflächen - aus der Ferne bleiben davon 24 nebeneinanderliegende
    # Linien à 1 px stehen, während die Füllfläche auf wenige Pixel schrumpft.
    # Der Turm wirkt dadurch aus der Distanz wie ein massiver Balken. Nur die
    # Füllfläche skaliert perspektivisch korrekt.
    tower.style.polystyle.color = simplekml.Color.changealphaint(220, color_tower)
    tower.style.polystyle.outline = 0
    tower.style.linestyle.color = color_tower
    tower.style.linestyle.width = 0

    # --- Gondel als Box ---
    # Realistische Proportionen basierend auf Herstellerdaten
    nacelle_length = max(8, diameter * 0.07)   # Ca. 7% des Rotordurchmessers (12m bei V172)
    nacelle_width = max(3, diameter * 0.025)   # Ca. 2.5% (4.3m bei V172)
    nacelle_height = max(3, diameter * 0.025)  # Ca. 2.5% (4.3m bei V172)

    heading_rad = math.radians(rotor_heading)

    def local_to_lonlat(along, across):
        """Lokale Gondelkoordinaten -> (lon, lat).

        along zeigt in Richtung rotor_heading, across 90° im Uhrzeigersinn dazu.
        Bewusst dieselbe Kompasskonvention wie compass_offset(): früher rechnete
        diese Funktion mit einer mathematischen Drehung, wodurch die Gondel gegen
        Nabe und Rotor verdreht stand (identisch nur bei 45° und 225°).
        """
        east_a, north_a = compass_offset(along, heading_rad)
        east_c, north_c = compass_offset(across, heading_rad + math.pi / 2)
        return (lon + (east_a + east_c) * meter_to_deg_lon,
                lat + (north_a + north_c) * meter_to_deg_lat)

    half_len = nacelle_length / 2
    half_wid = nacelle_width / 2
    corners = [local_to_lonlat(-half_len, -half_wid),
               local_to_lonlat(half_len, -half_wid),
               local_to_lonlat(half_len, half_wid),
               local_to_lonlat(-half_len, half_wid)]

    nacelle_top = [(x, y, height + nacelle_height) for x, y in corners]
    nacelle_top = close_ring(nacelle_top)

    # Gondel Oberseite mit Extrusion nach unten
    nacelle = kmlfolder.newpolygon(
        name=f"{name} Gondel",
        outerboundaryis=nacelle_top,
        altitudemode=simplekml.AltitudeMode.relativetoground,
        extrude=1,
        visibility=visibility
    )
    nacelle.style.polystyle.color = simplekml.Color.changealphaint(220, color_nacelle)
    nacelle.style.polystyle.outline = 0   # dieselbe Pixelfalle wie beim Turm
    nacelle.style.linestyle.color = color_nacelle
    nacelle.style.linestyle.width = 0

    # --- Rotorblätter als vertikale Linien ---
    # Die Rotorebene steht senkrecht zur Erdoberfläche und senkrecht zur Gondel
    blade_length = diameter / 2

    # Nabe an der Vorderseite der Gondel
    hub_east, hub_north = compass_offset(nacelle_length / 2, heading_rad)
    hub_lon = lon + hub_east * meter_to_deg_lon
    hub_lat = lat + hub_north * meter_to_deg_lat
    hub_height = height + nacelle_height / 2

    # Richtung senkrecht zur Gondel (horizontale Achse der Rotorebene)
    perp_heading_rad = heading_rad + math.pi / 2

    for blade_num in range(3):
        # Winkel im Rotorkreis (0° = oben, dann 120°, 240°)
        blade_rad = math.radians(blade_num * 120)

        vertical_offset = blade_length * math.cos(blade_rad)     # Höhe relativ zur Nabe
        horizontal_offset = blade_length * math.sin(blade_rad)   # in der Rotorebene

        tip_east, tip_north = compass_offset(horizontal_offset, perp_heading_rad)

        blade_coords = [
            (hub_lon, hub_lat, hub_height),
            (hub_lon + tip_east * meter_to_deg_lon,
             hub_lat + tip_north * meter_to_deg_lat,
             hub_height + vertical_offset)
        ]

        blade = kmlfolder.newlinestring(
            name=f"{name} Rotor {blade_num + 1}",
            coords=blade_coords,
            altitudemode=simplekml.AltitudeMode.relativetoground
        )
        blade.style.linestyle.color = color_rotor
        # Ein Blatt lässt sich nur als Linie darstellen, deren Breite in Pixeln
        # gilt. 3 px blieben aus jeder Entfernung 3 px und ließen den Rotor aus
        # der Ferne massiver wirken als den Turm.
        blade.style.linestyle.width = 1
        blade.visibility = visibility


def polygons_of(geometry):
    """Zerlegt eine (Multi-)Polygon-Geometrie in eine Liste einzelner Polygone."""
    if geometry.geom_type == 'MultiPolygon':
        return list(geometry.geoms)
    return [geometry]


def exterior_coords(polygon, height=0):
    """Äußerer Ring eines Polygons als (lon, lat, height)-Liste."""
    return [(c[0], c[1], height) for c in polygon.exterior.coords]


def flat_coords(polygon, height=0):
    """Äußerer Ring als flache Liste [lon, lat, height, lon, lat, height, ...].

    Dieses Format erwartet Cesium.Cartesian3.fromDegreesArrayHeights im Viewer.
    """
    flat = []
    for c in polygon.exterior.coords:
        flat.extend([c[0], c[1], height])
    return flat


_shapefile_cache = {}


def load_shapefile(path, epsg=4326):
    """Lädt ein Shapefile nach WGS84 und merkt es sich für weitere Zellen."""
    key = (path, epsg)
    if key not in _shapefile_cache:
        _shapefile_cache[key] = gpd.read_file(path).to_crs(epsg=epsg)
    return _shapefile_cache[key]


def clip_to_project_area(gdf):
    """Beschränkt ein GeoDataFrame auf den Projektbereich (Bösingen-Region)."""
    return gdf.cx[CONFIG['area_lon_min']:CONFIG['area_lon_max'],
                  CONFIG['area_lat_min']:CONFIG['area_lat_max']]


def csv2df(filename):
    """Lädt CSV-Datei und bereinigt Koordinatendaten"""
    df = pd.read_csv(filename, sep=',', decimal='.', header=0)
    df = df.dropna(axis=0, subset=['Latitude', 'Longitude'])
    df = df[df['Latitude'] != '']
    df = df[df['Longitude'] != '']
    df['Latitude'] = df['Latitude'].astype(np.float64)
    df['Longitude'] = df['Longitude'].astype(np.float64)

    if 'visible' in df.columns:
        df['visible'] = df['visible'].fillna(1).astype(int)
    else:
        df['visible'] = 1
    return df


def load_wvg_csv_polygons():
    """Windvorranggebiete aus den CSV-Fallback-Dateien.

    Yields:
        (name, [(lon, lat, alt), ...])
    """
    for wvg_file in sorted(glob.glob('areas/windvorranggebiet_*.csv')):
        number = os.path.splitext(os.path.basename(wvg_file))[0].split('_')[-1]
        try:
            df = pd.read_csv(wvg_file)
            coords = list(zip(df['Longitude'], df['Latitude'], df['Altitude']))
        except Exception as e:
            print(f"  Fehler bei {wvg_file}: {e}")
            continue
        yield f"Windvorranggebiet {number}", coords


def is_in_area(lon, lat):
    """Prüft ob Koordinaten im definierten Gebiet liegen"""
    return (CONFIG['area_lat_min'] <= lat <= CONFIG['area_lat_max'] and
            CONFIG['area_lon_min'] <= lon <= CONFIG['area_lon_max'])


def track_ground_reference(raw_extractor, path, samples=5):
    """Bodenhöhe einer Trackdatei aus ihren eigenen Rohdaten.

    Der erste Fix liegt am Boden (Start am Flugplatz), sein Höhenwert ist
    deshalb die Nullreferenz für diese Datei. Bewusst NICHT die Platzhöhe aus
    CONFIG: jeder Logger hat einen eigenen Offset (GPS-Ellipsoid vs. Geoid,
    Baro-Kalibrierung), und Google Earths Gelände weicht ohnehin von echtem MSL
    ab. Beobachtet wurden hier 692-697 m für denselben Startplatz.

    Median der ersten Fixes statt nur des ersten, damit ein einzelner
    GPS-Ausreißer beim Einschalten die Referenz nicht verschiebt.

    Returns:
        Bodenhöhe in Metern oder None, wenn die Datei nicht lesbar ist.
    """
    try:
        raw, _, _ = raw_extractor(path)
        if raw is None or 'Altitude' not in raw:
            return None
        head = pd.to_numeric(raw['Altitude']).head(samples)
        return float(head.median()) if len(head) else None
    except Exception:
        return None


def add_flight_tracks(kml_folder, pattern, extractor, color, raw_extractor,
                      min_altitude=710, max_altitude=1500, min_climb_rate=0):
    """Liest Flugtracks ein und hängt sie als Linien an einen KML-Ordner.

    Gemeinsame Logik für KML- und IGC-Tracks; extractor ist
    kml_extract_launch_phase bzw. igc_extract_launch_phase, raw_extractor die
    zugehörige ungefilterte Variante (*_extract_altitude_section) für die
    Bodenreferenz.

    Die Höhen der Quelldateien sind absolute MSL-Werte; gezeichnet wird über
    Grund. min_altitude/max_altitude filtern weiterhin auf den absoluten
    Rohwerten (710 m entspricht rund 20 m über dem Platz).

    Returns:
        (anzahl_hinzugefuegt, anzahl_uebersprungen)
    """
    added = skipped = 0

    for path in sorted(glob.glob(pattern)):
        try:
            track, flight_url, flight_name = extractor(
                path, min_altitude=min_altitude, max_altitude=max_altitude,
                min_climb_rate=min_climb_rate
            )

            if track is None:
                skipped += 1
                continue

            ground = track_ground_reference(raw_extractor, path)
            if ground is None:
                print(f"  Übersprungen (keine Bodenreferenz): {flight_name}")
                skipped += 1
                continue

            coordinates = [(lon, lat, alt - ground) for lon, lat, alt in
                           track[['Longitude', 'Latitude', 'Altitude']].values.tolist()]

            # Tracks außerhalb der Region überspringen
            if not is_in_area(coordinates[0][0], coordinates[0][1]):
                print(f"  Übersprungen (außerhalb Gebiet): {flight_name}")
                skipped += 1
                continue

            # Eine Linie braucht mindestens zwei verschiedene Punkte. Google
            # Earth Web setzt solche Entartungen sonst auf Position 0,0.
            if len({(lon, lat) for lon, lat, _ in coordinates}) < 2:
                print(f"  Übersprungen (weniger als 2 eindeutige Punkte): {flight_name}")
                skipped += 1
                continue

            create_kml_line(kml_folder, coordinates, flight_name, flight_url, color)
            added += 1

        except Exception as e:
            print(f"  Fehler bei {path}: {e}")
            skipped += 1

    return added, skipped


def promote_styles_to_document(kml_path):
    """Hebt alle Shared Styles in das <Document> der Datei.

    simplekml legt einen per styleUrl referenzierten Style in den Folder, in dem
    das erste nutzende Feature entstanden ist. Nach KML-Spezifikation sind
    Shared Styles (Style/StyleMap mit id) aber nur direkt unter <Document>
    gültig. Google Earth Pro ist tolerant, Google Earth WEB nicht: dort
    scheitert dann jede styleUrl-Referenz mit "verweist auf den nicht
    vorhandenen Stil" und die Geometrie erscheint ungestylt.

    Returns:
        Anzahl der verschobenen Stile.
    """
    ns = 'http://www.opengis.net/kml/2.2'
    ET.register_namespace('', ns)
    ET.register_namespace('gx', 'http://www.google.com/kml/ext/2.2')

    tree = ET.parse(kml_path)
    root = tree.getroot()
    document = root.find(f'{{{ns}}}Document')
    if document is None:
        raise ValueError(f"{kml_path}: kein <Document> - Wurzel muss "
                         "simplekml.Document sein, sonst sind Shared Styles ungültig.")

    parents = {child: parent for parent in root.iter() for child in parent}

    moved = []
    for tag in ('Style', 'StyleMap'):
        for style in root.iter(f'{{{ns}}}{tag}'):
            parent = parents.get(style)
            if 'id' in style.attrib and parent is not None and parent is not document:
                moved.append((parent, style))

    for parent, style in moved:
        parent.remove(style)

    # Stile vor die Features setzen, hinter die beschreibenden Kopfelemente.
    header = {f'{{{ns}}}{t}' for t in ('name', 'visibility', 'open', 'description')}
    insert_at = 0
    for index, child in enumerate(document):
        if child.tag not in header:
            break
        insert_at = index + 1

    for offset, (_, style) in enumerate(moved):
        document.insert(insert_at + offset, style)

    tree.write(kml_path, encoding='UTF-8', xml_declaration=True)
    return len(moved)


def save_kml(kml_obj, path, label):
    """Speichert ein KML und macht es Google-Earth-Web-tauglich."""
    kml_obj.save(path)
    moved = promote_styles_to_document(path)
    size = os.path.getsize(path) / 1024
    print(f"{label}: {path} ({size:.0f} KB, {moved} Stile ins <Document> gehoben)")
    return path

print("Hilfsfunktionen geladen.")

# %%
# ============================================================================
# 3D-MODELLE ERZEUGEN (COLLADA)
# ============================================================================
# https://www.wind-turbine-models.com/turbines/2425-vestas-v172-7.2-enventus
# https://www.koordinaten-umrechner.de/decimal/48.237694,8.524661?karte=OpenStreetMap&zoom=16

# Anlagentypen mit ihren Bauparametern. Die Nabenhöhe (tower_height) und der
# Rotordurchmesser müssen zu den Werten in locations/*.csv passen.
# blade_chord ist die GRÖSSTE Blatttiefe (bei rund 20 % der Blattlänge), nicht
# mehr die Tiefe an der Wurzel: der Tiefenverlauf kommt aus
# collada_wt.BLADE_PLANFORM und verjüngt sich zur Spitze hin auf wenige
# Zentimeter. blade_tip_size wird deshalb nicht mehr ausgewertet.
#
# blade_tip_paint_length ist die rot markierte Blattspitze - 6 m entsprechend
# der AVV Kennzeichnung von Luftfahrthindernissen.
#
# Die Türme verjüngen sich jetzt deutlich (Kopfdurchmesser rund halber
# Fußdurchmesser). Vorher liefen sie mit 6 m unten auf 5 m oben praktisch
# zylindrisch und wirkten dadurch massiv.
TURBINE_MODELS = {
    # Vestas V172, Bösingen
    'vestas-v172.dae': dict(
        tower_height=199, tower_bot_diameter=6.5, tower_top_diameter=3.5,
        nacelle_height=3, nacelle_length=20, nacelle_overhang=8,
        rotor_diameter=172, blade_root_length=3.5, blade_root_diameter=3,
        blade_chord=4.5, blade_twist=30, blade_tip_paint_length=6,
    ),
    # Enercon E66/1500 (Nennleistung 1500 kW), Dunningen
    'enercon-e-66.dae': dict(
        tower_height=95, tower_bot_diameter=4.5, tower_top_diameter=2.5,
        nacelle_height=3, nacelle_length=10, nacelle_overhang=4,
        rotor_diameter=66, blade_root_length=2.5, blade_root_diameter=2,
        blade_chord=2.5, blade_twist=30, blade_tip_paint_length=6,
    ),
    # Enercon E160, Herrenzimmern
    'enercon-e-160.dae': dict(
        tower_height=166, tower_bot_diameter=6, tower_top_diameter=3.5,
        nacelle_height=3, nacelle_length=15, nacelle_overhang=6,
        rotor_diameter=160, blade_root_length=3, blade_root_diameter=2.5,
        blade_chord=4.5, blade_twist=30, blade_tip_paint_length=6,
    ),
}

# Reine Zylinder ohne Rotor (Messmast / Testturm)
ZONE_MODELS = {
    'testturm.dae': dict(zone_height=246, zone_diameter=24.8),
}

os.makedirs(CONFIG['models_dir'], exist_ok=True)

for filename, params in TURBINE_MODELS.items():
    path = os.path.join(CONFIG['models_dir'], filename)
    collada_wt.create_turbine(**params).write(path)
    print(f"  {filename}: Nabenhöhe {params['tower_height']}m, "
          f"Rotor {params['rotor_diameter']}m")

for filename, params in ZONE_MODELS.items():
    path = os.path.join(CONFIG['models_dir'], filename)
    collada_wt.create_zone(**params).write(path)
    print(f"  {filename}: Höhe {params['zone_height']}m, "
          f"Durchmesser {params['zone_diameter']}m")

print(f"\n{len(TURBINE_MODELS) + len(ZONE_MODELS)} COLLADA-Modelle geschrieben "
      f"nach {CONFIG['models_dir']}/")

# %%
# ============================================================================
# COLLADA ZU GLTF KONVERTIEREN (für Cesium)
# ============================================================================
# Cesium verwendet glTF als natives 3D-Format. Die COLLADA-Modelle werden
# nach GLB (binäres glTF) konvertiert für optimale Performance.

def convert_dae_to_glb(dae_path, glb_path=None):
    """Konvertiert eine COLLADA-Datei (.dae) nach GLB (binäres glTF)."""
    if glb_path is None:
        glb_path = dae_path.replace('.dae', '.glb')

    scene = trimesh.load(dae_path)
    scene.export(glb_path, file_type='glb')
    return glb_path


print("Konvertiere COLLADA-Modelle nach glTF...")

glb_models = {}
for dae_file in sorted(glob.glob(f"{CONFIG['models_dir']}/*.dae")):
    model_name = os.path.basename(dae_file)
    glb_file = dae_file.replace('.dae', '.glb')

    try:
        convert_dae_to_glb(dae_file, glb_file)
    except Exception as e:
        print(f"  Fehler bei {model_name}: {e}")
        continue

    glb_size = os.path.getsize(glb_file) / 1024
    print(f"  {model_name} -> {os.path.basename(glb_file)} ({glb_size:.1f} KB)")
    glb_models[model_name] = os.path.basename(glb_file)

print(f"\n{len(glb_models)} Modelle konvertiert.")

# %%
# ============================================================================
# WINDTURBINEN AUS CSV LADEN
# ============================================================================

def add_turbine(row, folder_model, folder_extent, folder_safety,
                folder_marker, markerstyle, color_extent=simplekml.Color.firebrick,
                visibility=1):
    """Fügt eine Windturbine mit allen zugehörigen KML-Elementen hinzu"""
    name = row['Name']
    latitude = row['Latitude']
    longitude = row['Longitude']
    height = row['height']
    diameter = row['diameter']

    actual_visibility = visibility if row.get('visible', 1) == 1 else 0

    # 3D-Modell (nur in Google Earth Pro Desktop sichtbar)
    turbine = folder_model.newmodel(name=name)
    turbine.link.href = f"{CONFIG['models_dir']}/{row['Model']}"
    turbine.location.latitude = latitude
    turbine.location.longitude = longitude
    turbine.scale.x = 1
    turbine.scale.y = 1
    turbine.scale.z = 1
    turbine.visibility = actual_visibility
    turbine.orientation.heading = ROTOR_ORIENTATION

    # Umfang als Zylinder
    create_kml_cylinder(
        kmlfolder=folder_extent,
        cyl_center=(longitude, latitude),
        cyl_diameter=diameter,
        cyl_height=height + diameter / 2,
        cyl_color=color_extent,
        cyl_name=name,
        cyl_visibility=0
    )

    # Sicherheitszone als Zylinder
    safety_distance = max(CONFIG['safety_distance_meter'],
                          diameter * CONFIG['safety_distance_factor'])
    if folder_safety is not None:
        create_kml_cylinder(
            kmlfolder=folder_safety,
            cyl_center=(longitude, latitude),
            cyl_diameter=diameter + safety_distance * 2,
            cyl_height=height + diameter / 2 + CONFIG['safety_distance_top'],
            cyl_color=simplekml.Color.lightgray,
            cyl_name=name,
            cyl_visibility=0
        )

    # Standort-Marker
    if folder_marker is not None and markerstyle is not None:
        location = folder_marker.newpoint(name=name, coords=[(longitude, latitude)])
        location.style = markerstyle
        location.visibility = 0


def get_marker_style(folder_name):
    """Gibt den passenden Marker-Stil basierend auf dem Ordnernamen zurück"""
    markerstyle = simplekml.Style()
    markerstyle.labelstyle.scale = 0.8
    markerstyle.iconstyle.icon.href = 'http://maps.google.com/mapfiles/kml/shapes/placemark_circle.png'

    colors = {
        'badenova': simplekml.Color.lightblue,
        'iterra': simplekml.Color.red,
    }
    markerstyle.labelstyle.color = simplekml.Color.lightgray
    markerstyle.iconstyle.color = colors.get(folder_name.lower(), simplekml.Color.darkgray)
    return markerstyle


def get_extent_color(folder_name):
    """Gibt die passende Umfang-Farbe basierend auf dem Ordnernamen zurück"""
    colors = {
        'iterra': simplekml.Color.darkorange,
        'testturm': simplekml.Color.silver,
    }
    return colors.get(folder_name.lower(), simplekml.Color.firebrick)


def make_subfolder(parent, folder_name, label, visibility):
    """Legt einen Unterordner an - je nach DIRECTORY_NESTING verschachtelt oder flach.

    Ohne Verschachtelung (parent is None) landen alle Ordner direkt unter dem
    Wurzeldokument, weil manche KML-Betrachter nur eine Ebene unterstützen.
    """
    if parent is not None:
        sub = parent.newfolder(name=label)
    else:
        sub = kml.newfolder(name=f'{folder_name}-{label}')
    sub.visibility = visibility
    return sub


# Alle CSV-Dateien im locations-Verzeichnis verarbeiten
csv_files = sorted(glob.glob('locations/*.csv'))
total_turbines = 0

for csv_file in csv_files:
    folder_name = os.path.splitext(os.path.basename(csv_file))[0].title()
    print(f"Verarbeite: {folder_name}")

    # Wurzelordner des Standorts - nur bei aktivierter Verschachtelung.
    # Früher blieb "folder" bei DIRECTORY_NESTING=False ungebunden und die
    # Testturm-Zweig löste einen NameError aus.
    folder = kml.newfolder(name=folder_name) if DIRECTORY_NESTING else None
    if folder is not None:
        folder.visibility = 0

    is_testturm = folder_name.lower() == 'testturm'

    folder_model = make_subfolder(folder, folder_name, 'Modell', 1)
    folder_extent = make_subfolder(folder, folder_name, 'Umfang', 0)

    if is_testturm:
        folder_safety = None
        folder_marker = None
        markerstyle = None
        if folder is not None:
            folder.visibility = 1
    else:
        folder_safety = make_subfolder(folder, folder_name, 'Sicherheitsabstand', 0)
        folder_marker = make_subfolder(folder, folder_name, 'Standorte', 0)
        markerstyle = get_marker_style(folder_name)

    try:
        df = csv2df(csv_file)
    except Exception as e:
        print(f"  -> Fehler beim Laden: {e}")
        continue

    color_extent = get_extent_color(folder_name)
    visible_turbines = df[df['visible'] == 1]

    for _, row in visible_turbines.iterrows():
        try:
            add_turbine(row, folder_model, folder_extent, folder_safety,
                        folder_marker, markerstyle,
                        color_extent=color_extent, visibility=1)
        except Exception as e:
            print(f"  -> Fehler bei {row.get('Name', '?')}: {e}")

    count = len(visible_turbines)
    total_turbines += count
    if len(df) != count:
        print(f"  -> {count}/{len(df)} sichtbare Turbinen")
    else:
        print(f"  -> {count} Turbinen")

print(f"\nGesamt: {total_turbines} Turbinen aus {len(csv_files)} CSV-Dateien")

# %%
# ============================================================================
# FLUGPLATZ BÖSINGEN
# ============================================================================

folder_airfield = kml.newfolder(name='Flugplatz')
folder_airfield.visibility = 0
airfield_boesingen = CONFIG['airfield_boesingen']

# Landebahn
pol = folder_airfield.newpolygon(
    name="Landebahn",
    outerboundaryis=LANDEBAHN_COORDS,
    **CLAMPED
)
pol.style.polystyle.color = simplekml.Color.changealphaint(100, simplekml.Color.blue)

# Schutzzone (2 km Radius)
pol = folder_airfield.newpolygon(
    name="Schutzzone",
    outerboundaryis=circle_coords(airfield_boesingen, 2000, height=0),
    visibility=0,
    **CLAMPED
)
pol.style.polystyle.color = simplekml.Color.changealphaint(0, simplekml.Color.red)
pol.style.linestyle.color = simplekml.Color.red
pol.style.linestyle.width = 2

# Endanflugbereich (5 km Radius, 500 m über Grund)
create_kml_cylinder(
    kmlfolder=folder_airfield,
    cyl_center=airfield_boesingen,
    cyl_diameter=10000,
    cyl_height=500.0,
    cyl_color=simplekml.Color.changealphaint(100, simplekml.Color.green),
    cyl_name='Endanflugbereich',
    cyl_visibility=0
)

print("Flugplatz Bösingen erstellt.")

# %%
# ============================================================================
# WINDVORRANGGEBIETE AUS SHAPEFILE LADEN (RVSBH Teilplan Windkraft)
# ============================================================================
# Lädt alle offiziellen Windvorranggebiete aus dem RVSBH Shapefile.
# Keine räumliche Filterung - alle Gebiete werden eingezeichnet.
# Fällt auf die CSV-Dateien in areas/ zurück, wenn das Shapefile fehlt.

def style_wvg_polygon(pol):
    """Einheitliche Darstellung der Windvorranggebiete: gelb mit rotem Rand."""
    pol.style.polystyle.color = simplekml.Color.changealphaint(100, simplekml.Color.yellow)
    pol.style.linestyle.color = simplekml.Color.red
    pol.style.linestyle.width = 2


use_shapefile = True
gdf_wka = None

try:
    gdf_wka = load_shapefile(CONFIG['wka_shapefile'])
    print(f"WKA-Shapefile geladen: {len(gdf_wka)} Gebiete (RVSBH Teilplan Windkraft)")
    if len(gdf_wka) == 0:
        print("  -> Keine Windvorranggebiete gefunden")
        use_shapefile = False
except FileNotFoundError:
    print(f"WKA-Shapefile nicht gefunden: {CONFIG['wka_shapefile']}")
    print("  -> Verwende CSV-Dateien als Fallback")
    use_shapefile = False
except Exception as e:
    print(f"Fehler beim Laden des WKA-Shapefiles: {e}")
    print("  -> Verwende CSV-Dateien als Fallback")
    use_shapefile = False

if use_shapefile:
    folder_wvg = kml.newfolder(name='Windvorranggebiete (RVSBH)')
    folder_wvg.visibility = 0

    wvg_count = 0
    for idx, row in gdf_wka.iterrows():
        nr = row.get('nr', idx)
        inkraft = row.get('inkraft', '')
        polygons = polygons_of(row.geometry)

        for i, poly in enumerate(polygons):
            name = f"Windvorranggebiet {nr}"
            poly_name = name if len(polygons) == 1 else f"{name} ({i + 1})"

            pol = folder_wvg.newpolygon(
                name=poly_name,
                outerboundaryis=exterior_coords(poly),
                **CLAMPED
            )
            style_wvg_polygon(pol)
            pol.description = f"RVSBH Nr. {nr}<br/>Inkrafttreten: {inkraft}"
            wvg_count += 1

    print(f"  -> {wvg_count} Windvorranggebiet-Polygone zum KML hinzugefügt")
else:
    # Fallback: CSV-Dateien verwenden
    folder_wvg = kml.newfolder(name='Windvorranggebiete')
    folder_wvg.visibility = 0

    wvg_count = 0
    for name, coordinates in load_wvg_csv_polygons():
        pol = folder_wvg.newpolygon(
            name=name,
            outerboundaryis=coordinates,
            **CLAMPED
        )
        style_wvg_polygon(pol)
        pol.description = name
        wvg_count += 1
        print(f"  {name}: {len(coordinates)} Koordinaten (CSV)")

    print(f"\n{wvg_count} Windvorranggebiete aus CSV geladen (Fallback)")

# %%
# ============================================================================
# FREIFLÄCHEN-PHOTOVOLTAIK (FFPV) AUS SHAPEFILE LADEN
# ============================================================================
# Lädt PV-Gebiete aus dem RVSBH Shapefile und fügt sie als Layer hinzu.
# Die Daten liegen in EPSG:25832 (UTM 32N) vor und werden nach WGS84
# transformiert. Anders als die Windvorranggebiete werden sie auf den
# Projektbereich beschränkt.

gdf_pv_filtered = None

try:
    gdf_pv = load_shapefile(CONFIG['ffpv_shapefile'])
    gdf_pv_filtered = clip_to_project_area(gdf_pv)

    print(f"FFPV-Shapefile geladen: {len(gdf_pv)} Gebiete total")
    print(f"  -> {len(gdf_pv_filtered)} Gebiete im Projektbereich")

    if len(gdf_pv_filtered) == 0:
        print("  -> Keine FFPV-Gebiete im Projektbereich gefunden")
    else:
        folder_pv = kml.newfolder(name='Freiflächen-PV (FFPV)')
        folder_pv.visibility = 0

        pv_count = 0
        for idx, row in gdf_pv_filtered.iterrows():
            name = row.get('Bez', f"PV-Gebiet {row.get('Gebietsnum', idx)}")
            gemeinde = row.get('Gemeinde', 'Unbekannt')
            polygons = polygons_of(row.geometry)

            for i, poly in enumerate(polygons):
                poly_name = name if len(polygons) == 1 else f"{name} ({i + 1})"

                pol = folder_pv.newpolygon(
                    name=poly_name,
                    outerboundaryis=exterior_coords(poly),
                    **CLAMPED
                )
                pol.style.polystyle.color = simplekml.Color.changealphaint(100, simplekml.Color.orange)
                pol.style.linestyle.color = simplekml.Color.darkorange
                pol.style.linestyle.width = 2
                pol.description = (f"Gemeinde: {gemeinde}<br/>"
                                   f"Gebietsnummer: {row.get('Gebietsnum', '-')}")
                pv_count += 1

        print(f"  -> {pv_count} FFPV-Polygone zum KML hinzugefügt")

except FileNotFoundError:
    print(f"FFPV-Shapefile nicht gefunden: {CONFIG['ffpv_shapefile']}")
except Exception as e:
    print(f"Fehler beim Laden des FFPV-Shapefiles: {e}")

# %%
# ============================================================================
# FLUGROUTEN
# ============================================================================

folder_routes = kml.newfolder(name='Flugrouten')
folder_routes.visibility = 0

lon, lat = CONFIG['airfield_boesingen']

# Platzrunde aus CSV laden.
# Die Datei liefert die Spalten in KML-Reihenfolge: Longitude, Latitude, Altitude.
# Die CSV-Höhen sind Meter über NN. Für die Darstellung werden sie auf Meter
# über Grund umgerechnet und mit relativeToGround gezeichnet: absolute Höhen
# unterstellen eine Geländehöhe, die nicht der von Google Earth entspricht -
# dadurch stand die Platzrunde sichtbar zu hoch und ohne Bezug zur Oberfläche.
df_platzrunde = csv2df('areas/platzrunde.csv')
platzrunde_msl = [tuple(c) for c in
                  df_platzrunde[['Longitude', 'Latitude', 'Altitude']].values.tolist()]
# Bodenreferenz aus den Daten: der erste Punkt liegt auf der Bahn.
ground_ref = platzrunde_msl[0][2]
platzrunde_agl = [(lon, lat, max(0.0, alt - ground_ref)) for lon, lat, alt in platzrunde_msl]

# Verdichten, damit die Linie zwischen den zehn Stützpunkten dem Gelände folgt.
coordinates = densify_path(close_ring(platzrunde_agl))

ls = folder_routes.newlinestring(
    name='Platzrunde',
    coords=coordinates,
    altitudemode=simplekml.AltitudeMode.relativetoground,
    extrude=1
)
ls.style.linestyle.color = simplekml.Color.red
ls.style.linestyle.width = 4
# Vorhang zum Boden: macht die Höhe über Grund ablesbar und bindet die
# Platzrunde sichtbar an die Oberfläche.
ls.style.polystyle.color = simplekml.Color.changealphaint(40, simplekml.Color.red)
ls.visibility = 1

# Anflugkorridore (60 km/h, 1 m/s Sinken). Länge/Breite in Kilometern,
# Starthöhe in Metern ÜBER GRUND: 0 = der Korridor setzt an der Bahn auf.
approach_slope = calculate_slope(60, 1)
create_kml_slope(folder_routes, lat, lon, 0, 270, 3, approach_slope, 0.3,
                 simplekml.Color.yellow, "Anflug 27")
create_kml_slope(folder_routes, lat, lon, 0, 90, 3, approach_slope, 0.3,
                 simplekml.Color.yellow, "Anflug 09")

# Abflugkorridor im Schleppverbund (60 km/h, 1.5 m/s Steigen).
# Starthöhe 60 m über Grund (entspricht der früheren Angabe 750 m ü. NN bei
# rund 690 m Platzhöhe).
# 500 m Westversatz: ein Längengrad ist auf 48° Breite nur
# 111.2 km * cos(48.23°) = 74.1 km breit - ohne diese Korrektur waren es
# tatsächlich nur rund 333 m.
departure_slope = calculate_slope(60, 1.5)
offset_deg_lon = 500 * degrees_per_meter(lat)[0]
create_kml_cube(folder_routes, lat, lon - offset_deg_lon, 60, 355, 5, departure_slope, 2,
                simplekml.Color.blue, "Abflug")

print("Flugrouten erstellt.")

# %%
# ============================================================================
# FLUGTRACKS AUS KML-DATEIEN
# ============================================================================

folder_tracks_kml = kml.newfolder(name='Tracks.KML')
folder_tracks_kml.visibility = 0

added, skipped = add_flight_tracks(
    folder_tracks_kml,
    os.path.join('tracks', 'kml', '*.kml'),
    kml_extract_launch_phase,
    simplekml.Color.purple,
    raw_extractor=kml_extract_altitude_section
)

print(f"\nKML-Tracks: {added} hinzugefügt, {skipped} übersprungen")

# %%
# ============================================================================
# FLUGTRACKS AUS IGC-DATEIEN
# ============================================================================

folder_tracks_igc = kml.newfolder(name='Tracks.IGC')
folder_tracks_igc.visibility = 0

added, skipped = add_flight_tracks(
    folder_tracks_igc,
    os.path.join('tracks', 'igc', '*.igc'),
    igc_extract_launch_phase,
    simplekml.Color.mediumpurple,
    raw_extractor=igc_extract_altitude_section
)

print(f"\nIGC-Tracks: {added} hinzugefügt, {skipped} übersprungen")

# %%
# ============================================================================
# KML SPEICHERN
# ============================================================================

save_kml(kml, CONFIG['output_kml'], "KML gespeichert")

# %%
# ============================================================================
# KMZ ERSTELLEN (KML + 3D-Modelle für Google Earth Pro)
# ============================================================================

def create_kmz(kml_filename, extra_files, output_filename):
    """Erstellt ein KMZ-Archiv aus KML und zusätzlichen Dateien.

    Das KML wird als 'doc.kml' in den Archiv-Wurzelordner geschrieben. Nur so
    lösen relative Verweise wie <href>models/x.dae</href> innerhalb des Archivs
    auf - vorher lag das KML unter 'output/' und die Modellpfade zeigten ins
    Leere. Zusätzlich wird komprimiert (vorher unkomprimiert gespeichert).
    """
    with zipfile.ZipFile(output_filename, 'w', zipfile.ZIP_DEFLATED) as kmz:
        kmz.write(kml_filename, 'doc.kml')
        for path in extra_files:
            kmz.write(path, path.replace(os.sep, '/'))


# Alle DAE-Modelle sammeln
dae_files = sorted(glob.glob(f"{CONFIG['models_dir']}/*.dae"))

# Pro-Version mit COLLADA-Modellen. Zielname ist CONFIG['output_kmz'] - vorher
# schrieb diese Zelle nach 'WEA-boesingen-pro.kmz', während README und CLAUDE.md
# 'WEA-boesingen.kmz' als Ergebnis nannten. Dadurch blieb dort eine alte Datei
# von Januar 2024 liegen, die bei jeder Prüfung mit angesehen wurde.
output_kmz_pro = CONFIG['output_kmz']
create_kmz(CONFIG['output_kml'], dae_files, output_kmz_pro)

kmz_size = os.path.getsize(output_kmz_pro) / 1024
print(f"KMZ für Google Earth Pro erstellt: {output_kmz_pro} ({kmz_size:.0f} KB)")
print(f"  - Enthält {len(dae_files)} 3D-Modelle (COLLADA)")
print(f"  - Für beste Darstellung in Google Earth Pro Desktop öffnen")

# %%
# ============================================================================
# WEB-KOMPATIBLE KMZ ERSTELLEN (ohne COLLADA-Modelle)
# ============================================================================
# Diese Version verwendet vereinfachte KML-Geometrie statt COLLADA-Modellen
# und funktioniert in Google Earth Web, iPad, und anderen KML-Viewern.

def get_turbine_color(folder_name):
    """Gibt passende Farben für Turm, Gondel und Rotor basierend auf Ordnernamen zurück"""
    color_map = {
        'badenova': (simplekml.Color.lightblue, simplekml.Color.blue, simplekml.Color.white),
        'iterra': (simplekml.Color.orange, simplekml.Color.darkorange, simplekml.Color.white),
        'testturm': (simplekml.Color.silver, simplekml.Color.gray, simplekml.Color.silver),
    }
    # Default: weiß/grau
    return color_map.get(folder_name.lower(),
                         (simplekml.Color.white, simplekml.Color.lightgray, simplekml.Color.white))


# Neues KML-Dokument für Web-Version
kml_web = simplekml.Kml()
kml_web.document = simplekml.Document(name="Windpark Bösingen (Web)")

print("Erstelle Web-kompatible KMZ...")

web_turbine_count = 0

for csv_file in sorted(glob.glob('locations/*.csv')):
    folder_name = os.path.splitext(os.path.basename(csv_file))[0].title()

    folder_web = kml_web.newfolder(name=folder_name)
    folder_web.visibility = 1 if 'testturm' in folder_name.lower() else 0

    folder_model_web = folder_web.newfolder(name='WEA-Modelle')
    folder_model_web.visibility = 1

    folder_extent_web = folder_web.newfolder(name='Umfang')
    folder_extent_web.visibility = 0

    color_tower, color_nacelle, color_rotor = get_turbine_color(folder_name)
    color_extent = get_extent_color(folder_name)

    try:
        df = csv2df(csv_file)
    except Exception as e:
        print(f"  Fehler bei {folder_name}: {e}")
        continue

    for _, row in df[df['visible'] == 1].iterrows():
        center = (row['Longitude'], row['Latitude'])

        # Vereinfachte WEA-Darstellung aus KML-Primitiven
        create_kml_turbine_simple(
            kmlfolder=folder_model_web,
            center=center,
            height=row['height'],
            diameter=row['diameter'],
            name=row['Name'],
            color_tower=color_tower,
            color_nacelle=color_nacelle,
            color_rotor=color_rotor,
            rotor_heading=ROTOR_ORIENTATION,
            visibility=1
        )

        # Umfang als Zylinder
        create_kml_cylinder(
            kmlfolder=folder_extent_web,
            cyl_center=center,
            cyl_diameter=row['diameter'],
            cyl_height=row['height'] + row['diameter'] / 2,
            cyl_color=color_extent,
            cyl_name=row['Name'],
            cyl_visibility=0
        )

        web_turbine_count += 1

print(f"  {web_turbine_count} vereinfachte WEA-Modelle erstellt")

# Windvorranggebiete hinzufügen
folder_wvg_web = kml_web.newfolder(name='Windvorranggebiete')
folder_wvg_web.visibility = 0

for name, coordinates in load_wvg_csv_polygons():
    pol = folder_wvg_web.newpolygon(
        name=name,
        outerboundaryis=coordinates,
        **CLAMPED
    )
    style_wvg_polygon(pol)

# Flugplatz (Landebahn, Schutzzone, Endanflugbereich), Flugrouten und Tracks
# aus der Pro-Version übernehmen. Der frühere web-eigene Flugplatz-Ordner
# enthielt nur die Landebahn und lag doppelt neben dem übernommenen. Diese
# Ordner enthalten keine COLLADA-Modelle, sind also web-tauglich, und wurden
# vorher nur in der Pro-Datei ausgeliefert - in der Web-Version fehlten
# Platzrunde, An-/Abflugkorridore und sämtliche Flugspuren.
for shared_folder in (folder_airfield, folder_routes, folder_tracks_kml, folder_tracks_igc):
    kml_web.document._features.append(shared_folder)

# Web-Version speichern
output_kml_web = os.path.join(CONFIG['output_dir'], 'WEA-boesingen-web.kml')
output_kmz_web = os.path.join(CONFIG['output_dir'], 'WEA-boesingen-web.kmz')

save_kml(kml_web, output_kml_web, "Web-KML gespeichert")
create_kmz(output_kml_web, [], output_kmz_web)

web_size = os.path.getsize(output_kmz_web) / 1024
print(f"\nWeb-kompatible Dateien erstellt:")
print(f"  - {output_kmz_web} ({web_size:.0f} KB, für Google Earth Web, iPad, etc.)")
print(f"\nHinweis: Die Web-Version zeigt vereinfachte WEA-Darstellungen.")
print(f"         Für detaillierte 3D-Modelle: {output_kmz_pro} in Google Earth Pro öffnen.")

# %%
# ============================================================================
# CZML FÜR CESIUM ERSTELLEN (mit glTF-Modellen)
# ============================================================================
# CZML ist Cesiums natives JSON-Format. Die Windturbinen werden als glTF-Modelle
# referenziert für fotorealistische 3D-Darstellung.

def heading_quaternion(lon, lat, heading_deg):
    """Einheitsquaternion für eine Kompassausrichtung, im erdfesten Bezugssystem.

    CZML kennt für 'orientation' nur unitQuaternion bzw. velocityReference -
    ein Objekt aus heading/pitch/roll ist ungültig und wurde von Cesium
    stillschweigend ignoriert, sodass alle Turbinen unausgerichtet blieben.

    Das Quaternion beschreibt die Drehung vom erdfesten System (ECEF) in das
    lokale Ost-Nord-Oben-System der Anlage, kombiniert mit der Drehung um die
    lokale Hochachse um heading (im Uhrzeigersinn ab Nord).

    Returns:
        [x, y, z, w]
    """
    lam = math.radians(lon)
    phi = math.radians(lat)
    h = math.radians(heading_deg)

    # Spalten: Ost, Nord, Oben - das lokale System im erdfesten Bezugssystem
    east = np.array([-math.sin(lam), math.cos(lam), 0.0])
    north = np.array([-math.sin(phi) * math.cos(lam), -math.sin(phi) * math.sin(lam), math.cos(phi)])
    up = np.array([math.cos(phi) * math.cos(lam), math.cos(phi) * math.sin(lam), math.sin(phi)])
    enu = np.column_stack([east, north, up])

    # Drehung um die Hochachse: im Uhrzeigersinn ab Nord = negative Z-Drehung
    cz, sz = math.cos(-h), math.sin(-h)
    rot_z = np.array([[cz, -sz, 0.0],
                      [sz, cz, 0.0],
                      [0.0, 0.0, 1.0]])

    m = enu @ rot_z

    # Rotationsmatrix -> Quaternion (Shepperd, numerisch stabile Variante)
    trace = m[0, 0] + m[1, 1] + m[2, 2]
    if trace > 0:
        s = math.sqrt(trace + 1.0) * 2
        w = 0.25 * s
        x = (m[2, 1] - m[1, 2]) / s
        y = (m[0, 2] - m[2, 0]) / s
        z = (m[1, 0] - m[0, 1]) / s
    elif m[0, 0] > m[1, 1] and m[0, 0] > m[2, 2]:
        s = math.sqrt(1.0 + m[0, 0] - m[1, 1] - m[2, 2]) * 2
        w = (m[2, 1] - m[1, 2]) / s
        x = 0.25 * s
        y = (m[0, 1] + m[1, 0]) / s
        z = (m[0, 2] + m[2, 0]) / s
    elif m[1, 1] > m[2, 2]:
        s = math.sqrt(1.0 + m[1, 1] - m[0, 0] - m[2, 2]) * 2
        w = (m[0, 2] - m[2, 0]) / s
        x = (m[0, 1] + m[1, 0]) / s
        y = 0.25 * s
        z = (m[1, 2] + m[2, 1]) / s
    else:
        s = math.sqrt(1.0 + m[2, 2] - m[0, 0] - m[1, 1]) * 2
        w = (m[1, 0] - m[0, 1]) / s
        x = (m[0, 2] + m[2, 0]) / s
        y = (m[1, 2] + m[2, 1]) / s
        z = 0.25 * s

    return [x, y, z, w]


def create_czml_turbine_model(turbine_id, name, lon, lat, model_file,
                              rotor_heading=225, scale=1.0):
    """Erstellt ein CZML-Paket für eine Windturbine mit glTF-Modell."""
    return {
        "id": turbine_id,
        "name": name,
        "position": {
            "cartographicDegrees": [lon, lat, 0]  # Modell steht auf dem Boden
        },
        "model": {
            "gltf": f"models/{model_file}",
            "scale": scale,
            "minimumPixelSize": 64,
            "maximumScale": 20000,
            "heightReference": "RELATIVE_TO_GROUND",
            "silhouetteColor": {
                "rgba": [255, 255, 255, 255]
            },
            "silhouetteSize": 1.0
        },
        "orientation": {
            "unitQuaternion": heading_quaternion(lon, lat, rotor_heading)
        }
    }


def create_czml_polygon(polygon_id, name, coordinates, color=None,
                        outline_color=None, height=0, extrude=False):
    """Erstellt ein CZML-Polygon-Paket."""
    color = color or [255, 255, 0, 100]
    outline_color = outline_color or [255, 0, 0, 255]

    czml_coords = []
    for coord in coordinates:
        czml_coords.extend([coord[0], coord[1], coord[2] if len(coord) > 2 else height])

    polygon_props = {
        "positions": {
            "cartographicDegrees": czml_coords
        },
        "material": {
            "solidColor": {
                "color": {
                    "rgba": color
                }
            }
        },
        "outline": True,
        "outlineColor": {
            "rgba": outline_color
        },
        "outlineWidth": 2
    }

    if extrude:
        polygon_props["extrudedHeight"] = 0
        polygon_props["height"] = height

    return {
        "id": polygon_id,
        "name": name,
        "polygon": polygon_props
    }


# CZML-Dokument erstellen
czml_document = [
    {
        "id": "document",
        "name": "Windpark Bösingen",
        "version": "1.0",
        "clock": {
            "currentTime": "2025-01-01T00:00:00Z",
            "multiplier": 1
        }
    }
]

# Windturbinen aus CSV-Dateien laden
print("Erstelle CZML mit glTF-Modellen...")
turbine_count = 0

for csv_file in sorted(glob.glob('locations/*.csv')):
    try:
        df = csv2df(csv_file)
    except Exception as e:
        print(f"  Fehler bei {csv_file}: {e}")
        continue

    for _, row in df[df['visible'] == 1].iterrows():
        turbine_id = row['Name'].replace(' ', '_').replace('-', '_')
        glb_model = glb_models.get(row['Model'], row['Model'].replace('.dae', '.glb'))

        czml_document.append(create_czml_turbine_model(
            turbine_id=turbine_id,
            name=row['Name'],
            lon=row['Longitude'],
            lat=row['Latitude'],
            model_file=glb_model,
            rotor_heading=ROTOR_ORIENTATION,
            scale=1.0
        ))
        turbine_count += 1

print(f"  {turbine_count} Windturbinen (glTF-Modelle)")

# Windvorranggebiete als Polygone
wvg_count = 0
for name, coordinates in load_wvg_csv_polygons():
    number = name.split()[-1]
    czml_document.append(create_czml_polygon(
        polygon_id=f"wvg_{number}",
        name=name,
        coordinates=coordinates,
        color=[255, 255, 0, 80],
        outline_color=[255, 0, 0, 255]
    ))
    wvg_count += 1

print(f"  {wvg_count} Windvorranggebiete")

# Flugplatz Landebahn (offener Ring - CZML schließt Polygone selbst)
czml_document.append(create_czml_polygon(
    polygon_id="airfield_runway",
    name="Landebahn Bösingen",
    coordinates=LANDEBAHN_COORDS[:-1],
    color=[0, 0, 255, 100],
    outline_color=[0, 0, 255, 255]
))
print("  Flugplatz")

# CZML speichern
output_czml = os.path.join(CONFIG['output_dir'], 'WEA-boesingen.czml')
with open(output_czml, 'w', encoding='utf-8') as f:
    json.dump(czml_document, f, indent=2)

print(f"\nCZML erstellt: {output_czml}")
print(f"  - {len(czml_document)} Pakete")
print(f"  - Referenziert glTF-Modelle aus models/*.glb")

# %%
# ============================================================================
# CESIUM ION UPLOAD-PAKET ERSTELLEN
# ============================================================================
# Erstellt ein ZIP-Archiv mit CZML und allen glTF-Modellen für den Upload.

output_cesium_zip = os.path.join(CONFIG['output_dir'], 'WEA-boesingen-cesium.zip')

with zipfile.ZipFile(output_cesium_zip, 'w', zipfile.ZIP_DEFLATED) as zf:
    zf.write(output_czml, 'WEA-boesingen.czml')
    for glb_file in sorted(glob.glob(f"{CONFIG['models_dir']}/*.glb")):
        zf.write(glb_file, f"models/{os.path.basename(glb_file)}")

print(f"Cesium Upload-Paket erstellt: {output_cesium_zip}")
print(f"  Größe: {os.path.getsize(output_cesium_zip) / 1024:.1f} KB")
print("\nInhalt:")
with zipfile.ZipFile(output_cesium_zip, 'r') as zf:
    for info in zf.infolist():
        print(f"  - {info.filename} ({info.file_size / 1024:.1f} KB)")

print("\n" + "=" * 60)
print("ANLEITUNG FÜR CESIUM ION:")
print("=" * 60)
print("1. Öffnen Sie https://ion.cesium.com")
print("2. Klicken Sie 'Add Data' -> 'Upload'")
print("3. Wählen Sie: " + output_cesium_zip)
print("4. Asset-Typ: 'CZML'")
print("5. Nach dem Upload: 'Open in Cesium Stories' für Visualisierung")
print("=" * 60)

# %%
# ============================================================================
# CESIUM HTML-VIEWER GENERIEREN
# ============================================================================
# Erstellt eine HTML-Datei mit CesiumJS, die die Windturbinen aus Cesium ion lädt.
# Das Access Token wird aus der .env-Datei gelesen (CESIUM_ION_TOKEN_READONLY).

# Asset-IDs der nach Cesium ion hochgeladenen Modelle.
# Nach einem erneuten Upload müssen diese IDs aktualisiert werden.
CESIUM_ASSET_IDS = {
    'vestas-v172.glb': 4409698,
    'enercon-e-160.glb': 4409699,
    'enercon-e-66.glb': 4409700,
    'testturm.glb': 4409701,
}

CESIUM_VERSION = '1.114'

load_dotenv()
cesium_token = os.environ.get('CESIUM_ION_TOKEN_READONLY', '')

# --- Turbinen-Daten sammeln ---
turbines_js = []
for csv_file in sorted(glob.glob('locations/*.csv')):
    try:
        df = csv2df(csv_file)
    except Exception as e:
        print(f"  {os.path.basename(csv_file)}: {e}")
        continue

    for _, row in df[df['visible'] == 1].iterrows():
        asset_id = CESIUM_ASSET_IDS.get(row['Model'].replace('.dae', '.glb'))
        if asset_id is None:
            continue
        turbines_js.append({
            'name': row['Name'],
            'lon': row['Longitude'],
            'lat': row['Latitude'],
            'height': row['height'],
            'assetId': asset_id,
        })

# --- Windvorranggebiete: alle Gebiete, ohne räumliche Filterung ---
wvg_coords_js = {}
try:
    for idx, row in load_shapefile(CONFIG['wka_shapefile']).iterrows():
        nr = row.get('nr', idx)
        polygons = polygons_of(row.geometry)
        for i, poly in enumerate(polygons):
            key = f"wvg{nr}" if len(polygons) == 1 else f"wvg{nr}_{i}"
            wvg_coords_js[key] = flat_coords(poly)
except Exception as e:
    print(f"  WKA für HTML: {e} - weiche auf CSV aus")
    for name, coords in load_wvg_csv_polygons():
        number = name.split()[-1]
        flat = []
        for lon_c, lat_c, alt_c in coords:
            flat.extend([lon_c, lat_c, alt_c])
        wvg_coords_js[f'wvg{number}'] = flat

# --- FFPV-Gebiete: nur Projektbereich ---
ffpv_coords_js = {}
try:
    gdf_pv_html = clip_to_project_area(load_shapefile(CONFIG['ffpv_shapefile']))
    for idx, row in gdf_pv_html.iterrows():
        name = row.get('Bez', f"PV-{row.get('Gebietsnum', idx)}")
        gebietsnum = row.get('Gebietsnum', str(idx))
        polygons = polygons_of(row.geometry)
        for i, poly in enumerate(polygons):
            key = f"ffpv_{gebietsnum}" if len(polygons) == 1 else f"ffpv_{gebietsnum}_{i}"
            ffpv_coords_js[key] = {'name': name, 'coords': flat_coords(poly)}
except Exception as e:
    print(f"  FFPV für HTML: {e}")

if not cesium_token:
    print("WARNUNG: CESIUM_ION_TOKEN_READONLY nicht in .env gefunden!")
    print("Bitte fügen Sie folgende Zeile zur .env-Datei hinzu:")
    print("  CESIUM_ION_TOKEN_READONLY=ihr_token_hier")
else:
    html_content = f'''<!DOCTYPE html>
<html lang="de">
<head>
    <meta charset="UTF-8">
    <title>Windpark Bösingen - Cesium</title>
    <script src="https://cesium.com/downloads/cesiumjs/releases/{CESIUM_VERSION}/Build/Cesium/Cesium.js"></script>
    <link href="https://cesium.com/downloads/cesiumjs/releases/{CESIUM_VERSION}/Build/Cesium/Widgets/widgets.css" rel="stylesheet">
    <style>
        html, body, #cesiumContainer {{ width: 100%; height: 100%; margin: 0; padding: 0; overflow: hidden; }}
    </style>
</head>
<body>
    <div id="cesiumContainer"></div>
    <script>
        // Cesium ion Access Token (Read-Only)
        Cesium.Ion.defaultAccessToken = '{cesium_token}';

        const viewer = new Cesium.Viewer("cesiumContainer", {{
            terrain: Cesium.Terrain.fromWorldTerrain()
        }});

        // Rotor heading ({ROTOR_ORIENTATION}deg clockwise from north)
        const rotorHeading = Cesium.Math.toRadians({ROTOR_ORIENTATION});
        const hpr = new Cesium.HeadingPitchRoll(rotorHeading, 0, 0);

        const turbines = {json.dumps(turbines_js)};

        turbines.forEach(t => {{
            const position = Cesium.Cartesian3.fromDegrees(t.lon, t.lat, 0);
            const orientation = Cesium.Transforms.headingPitchRollQuaternion(position, hpr);

            Cesium.IonResource.fromAssetId(t.assetId).then(resource => {{
                viewer.entities.add({{
                    name: t.name,
                    position: position,
                    orientation: orientation,
                    model: {{
                        uri: resource,
                        heightReference: Cesium.HeightReference.CLAMP_TO_GROUND,
                        minimumPixelSize: 64
                    }}
                }});
            }}).catch(err => console.error("Modell " + t.assetId + ":", err));
        }});

        // Wind priority areas (RVSBH shapefile, all areas) - yellow
        const wvgCoords = {json.dumps(wvg_coords_js)};

        Object.entries(wvgCoords).forEach(([id, coords]) => {{
            viewer.entities.add({{
                name: "Windvorranggebiet " + id.replace("wvg", ""),
                polygon: {{
                    hierarchy: Cesium.Cartesian3.fromDegreesArrayHeights(coords),
                    material: Cesium.Color.YELLOW.withAlpha(0.3),
                    outline: true,
                    outlineColor: Cesium.Color.RED,
                    outlineWidth: 2
                }}
            }});
        }});

        // FFPV areas - orange
        const ffpvData = {json.dumps(ffpv_coords_js)};

        Object.entries(ffpvData).forEach(([id, data]) => {{
            viewer.entities.add({{
                name: "FFPV: " + data.name,
                polygon: {{
                    hierarchy: Cesium.Cartesian3.fromDegreesArrayHeights(data.coords),
                    material: Cesium.Color.ORANGE.withAlpha(0.3),
                    outline: true,
                    outlineColor: Cesium.Color.DARKORANGE,
                    outlineWidth: 2
                }}
            }});
        }});

        // Fly to Bösingen
        viewer.camera.flyTo({{
            destination: Cesium.Cartesian3.fromDegrees(8.534, 48.25, 5000),
            orientation: {{
                heading: Cesium.Math.toRadians(0),
                pitch: Cesium.Math.toRadians(-45),
                roll: 0
            }}
        }});
    </script>
</body>
</html>'''

    output_html = os.path.join(CONFIG['output_dir'], 'windpark-cesium.html')
    with open(output_html, 'w', encoding='utf-8') as f:
        f.write(html_content)

    print(f"Cesium HTML-Viewer erstellt: {output_html}")
    print(f"  - {len(turbines_js)} Windturbinen")
    print(f"  - {len(wvg_coords_js)} Windvorranggebiete (RVSBH, alle)")
    print(f"  - {len(ffpv_coords_js)} FFPV-Gebiete (Projektbereich)")
    print("  - Token aus .env geladen (CESIUM_ION_TOKEN_READONLY)")
    print("\nHinweis: Die HTML-Datei kann lokal geöffnet oder auf einem Webserver gehostet werden.")

# %% [markdown]
# ## Quellen
#
# * https://www.landesrecht-bw.de/jportal/?quelle=jlink&docid=JURE060017391&psml=bsbawueprod.psml&max=true&doc.part=L&doc.norm=all
# * https://www.daec.de/media/files/2022/Fachbereiche/Umwelt/Leitfaden_Luftfahrthindernisse_14_03_2022.pdf
# * https://www.fsco.de/images/Dokumente/Studie_DLR.pdf
# * https://www.dhv.de/fileadmin/user_upload/aktuell_zu_halten/Gelaende/DHV_info_199_windkraft.pdf
# * http://www.pontepress.de/pdf/u12_201706.pdf
# * [Beteiligungsverfahren Teilplan "Regionalbedeutsame Windkraftanlagen"](https://www.regionalverband-sbh.de/seite/653796/beteiligungsverfahren-teilplan-regionalbedeutsame-windkraftanlagen.html)
# * [Windpark Bösingen](https://www.boesingen.de/aktuelles/Windpark/Windpark-Boesingen)
# * [Windpark Herrenzimmern](https://www.boesingen.de/aktuelles/Windpark/Windpark-Herrenzimmern)
#
#
#
# ## Regelungen
#
# * [Abstandsempfehlungen zu Wohn- und Mischgebieten](https://fachagentur-windenergie.de/fileadmin/files/Veroeffentlichungen/Planung/FA_Wind_Abstandsempfehlungen_Aktualisierung_3-2023.pdf): 700m in BaWü
# * [Abstand WKA DHV](https://www.dhv.de/piloteninfos/gelaende-luftraum-natur/fluggelaendeflugbetrieb/flugbetrieb/windkraftanlagen-und-fluggelaende/mindestabstand-laut-nfl/): 600m
# * [NfL 92/13](https://www.dhv.de/fileadmin/user_upload/files/2015/05/NfL_-_Abstand_zu_Anlagen.pdf): 400 Gegenanflug, sonst 850
# * [Raumnutzungskarte](./papers/Anlage_2.1_Raumnutzungskarte_Umsetzung_Landesflaechenziel_nord_Beilage_25_2023_TOP_5.pdf)
#
# ## Untersuchungen
#
# * [Wissenschaftlicher Dienst des Deutschen Bundestag WD 8 - 3000 - 007/22
# Zu Wirbelschleppen von Windparks](https://www.bundestag.de/resource/blob/919868/18b8e759ff8a4b782befd451138d4003/WD-8-007-22-pdf-data.pdf)
# * [Schreckgespenst Turbulenzen](./papers/Schreckgespenst_Turbulenz_v2.pdf)
#
# ## Presse
#
# * https://www.schwarzwaelder-bote.de/inhalt.dunningen-windkraft-projekt-liegt-erst-mal-auf-eis.ed5bc4b7-42df-470d-a7cb-97cd0315cbbd.html
#
#
# ## Flurstücke in Herrenzimmern, Fa. Alterric
#
# * https://www.schwarzwaelder-bote.de/inhalt.windpark-in-herrenzimmern-anlage-wird-mit-rotorblatt-246-meter-hoch.ef522d07-0ce3-4fe3-a14e-e5a5bc19a655.html
# * ENERCON E-160 https://www.enercon.de/de/windanlagen/e-160-ep5
# * Gewann Saugrube
# * Sponäcker
# * Waldflurstück in Kleinheide
#
#
# # Schattenwurf
#
# Höhe der WEA: 246 Meter
#
#
# [Herrenzimmern](https://www.suncalc.org/#/48.2127,8.5715,14/2024.12.20/14:11/246/1)
#
# [Kasperleshof 1](https://www.suncalc.org/#/48.255,8.5367,15/2026.02.01/10:34/246/1)
#
#
#
#
# ## Einschätzungen

# %%
import sys
import os

os.chdir('/home/rainerth/notebooks/wind-turbine-kml/')
# os.chdir(os.path.dirname(__file__))

#print(os.listdir('.'))
print(sys.path)

# sys.path.append('./collada_wt')

import collada_wt
import simplekml
# https://simplekml.readthedocs.io/en/latest/index.html

print(collada_wt.__file__)
# Out:
# ['/home/rainerth/notebooks', '/home/rainerth/anaconda3/lib/python38.zip', '/home/rainerth/anaconda3/lib/python3.8', '/home/rainerth/anaconda3/lib/python3.8/lib-dynload', '', '/home/rainerth/.local/lib/python3.8/site-packages', '/home/rainerth/anaconda3/lib/python3.8/site-packages', '/home/rainerth/anaconda3/lib/python3.8/site-packages/locket-0.2.1-py3.8.egg']
# /home/rainerth/notebooks/wind-turbine-kml/collada_wt/__init__.py

# %%
import zipfile

def create_kmz(kml_filename, dae_filenames, output_filename):
    with zipfile.ZipFile(output_filename, 'w') as kmz:
        kmz.write(kml_filename)

        for dae in dae_filenames:
            kmz.write(dae, os.path.join("models", os.path.basename(dae)))

#if __name__ == "__main__":

# Listet alle .dae-Dateien im "model"-Verzeichnis auf

dae_files = [os.path.join("models", f) for f in os.listdir("models") if f.endswith('.dae')]
kml_file = "wka-boesingen.kml"  # Ersetzen Sie dies durch den Pfad zu Ihrer KML-Datei
output_file = "wka-boesingen.kmz"
create_kmz(kml_file, dae_files, output_file)

# %%
# create turbine
# https://www.wind-turbine-models.com/turbines/2425-vestas-v172-7.2-enventus
# https://www.koordinaten-umrechner.de/decimal/48.237694,8.524661?karte=OpenStreetMap&zoom=16

collada_wt1 = collada_wt.create_turbine(tower_height=199,
                    tower_bot_diameter = 6,
                    tower_top_diameter = 5,
                    nacelle_height = 3,
                    nacelle_length = 20,
                    nacelle_overhang = 8,
                    rotor_diameter = 172,
                    blade_root_length = 3.5,
                    blade_root_diameter = 3,
                    blade_chord=4,
                    blade_tip_size=0.5,
                    blade_twist=30,
                )

collada_wt1.write('models/vestas-v172.dae')

collada_wt2 = collada_wt.create_turbine(tower_height=95,
                    tower_bot_diameter = 5,
                    tower_top_diameter = 4,
                    nacelle_height = 3,
                    nacelle_length = 10,
                    nacelle_overhang = 4,
                    rotor_diameter = 70,
                    blade_root_length = 2.5,
                    blade_root_diameter = 2,
                    blade_chord=4,
                    blade_tip_size=0.5,
                    blade_twist=30,
                )

collada_wt2.write('models/wka-2003.dae')


# WKA geplant
collada_zone = collada_wt.create_zone(
                    zone_height=199+172/2+100,
                    zone_diameter = 150*2+172,
                )
collada_zone.write('models/wka-safety-zone.dae')


# WKA 2003
collada_zone = collada_wt.create_zone(
                    zone_height=99+60/2+100,
                    zone_diameter = 150*2+60,
                )
collada_zone.write('models/wka-safety-zone-2003.dae')


# Testturm RW
collada_zone = collada_wt.create_zone(
                    zone_height=246,
                    zone_diameter = 24,
                )
collada_zone.write('models/testturm.dae')

# %%
# create kml for Google Earth
# https://www.schwarzwaelder-bote.de/inhalt.windenergieanlagen-in-boesingen-drei-plus-maximal-fuenf-im-gespraech.8840b7d3-7346-4f63-8c82-27f76a697bdd.html
#
kml = simplekml.Kml()

# Bösingen

model = kml.newmodel(name='WKA-B1')
# model.description = "WEA Vestas V172"
model.link.href = 'models/vestas-v172.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.246568
model.location.longitude = 8.527107
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = kml.newmodel(name='WKA-B1-safety',)
model.link.href = 'models/wka-safety-zone.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.246568
model.location.longitude = 8.527107
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = kml.newmodel(name='WKA-B2',)
# model.description = "WEA Vestas V172"
model.link.href = 'models/vestas-v172.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.239080
model.location.longitude = 8.521872
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = kml.newmodel(name='WKA-B2-safety',)
model.link.href = 'models/wka-safety-zone.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.239080
model.location.longitude = 8.521872
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = kml.newmodel(name='WKA-B3',)
# model.description = "WEA Vestas V172"
model.link.href = 'models/vestas-v172.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.237594
model.location.longitude = 8.531227
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = kml.newmodel(name='WKA-B3-safety',)
model.link.href = 'models/wka-safety-zone.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.237594
model.location.longitude = 8.531227
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

# Dunningen
model = kml.newmodel(name='WKA-D1',)
model.link.href = 'models/wka-2003.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.219839
model.location.longitude = 8.532344
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = kml.newmodel(name='WKA-D1-safety',)
model.link.href = 'models/wka-safety-zone-2003.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.219839
model.location.longitude = 8.532344
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1


model = kml.newmodel(name='WKA-D2',)
model.link.href = 'models/wka-2003.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.221684
model.location.longitude = 8.527035
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = kml.newmodel(name='WKA-D2-safety',)
model.link.href = 'models/wka-safety-zone-2003.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.221684
model.location.longitude = 8.527035
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1


model = kml.newmodel(name='WKA-D3',)
model.link.href = 'models/wka-2003.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.221112
model.location.longitude = 8.522828
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = kml.newmodel(name='WKA-D3-safety',)
model.link.href = 'models/wka-safety-zone-2003.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.221112
model.location.longitude = 8.522828
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1


# Herrenzimmern
model = kml.newmodel(name='WKA-H1',)
model.link.href = 'models/vestas-v172.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.212488
model.location.longitude = 8.575546
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = kml.newmodel(name='WKA-H1-safety',)
model.link.href = 'models/wka-safety-zone.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.212488
model.location.longitude = 8.575546
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = kml.newmodel(name='WKA-H2',)
model.link.href = 'models/vestas-v172.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.208998
model.location.longitude = 8.555794
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = kml.newmodel(name='WKA-H2-safety',)
model.link.href = 'models/wka-safety-zone.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.208998
model.location.longitude = 8.555794
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = kml.newmodel(name='WKA-H3',)
model.link.href = 'models/vestas-v172.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.209003
model.location.longitude = 8.541822
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = kml.newmodel(name='WKA-H3-safety',)
model.link.href = 'models/wka-safety-zone.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.209003
model.location.longitude = 8.541822
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = kml.newmodel(name='Testturm',)
model.link.href = 'models/testturm.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.179222
model.location.longitude = 8.625056
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = kml.newmodel(name='Testturm-Vergleich',)
# model.description = "Thyssen Testturm zum Vergleich, 246m"
model.link.href = 'models/testturm.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.237594
model.location.longitude = 8.531227
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

kml_file = './wka-boesingen.kml'
kml.save(kml_file)

# %% [markdown]
# ## Quellen
#
# * https://www.landesrecht-bw.de/jportal/?quelle=jlink&docid=JURE060017391&psml=bsbawueprod.psml&max=true&doc.part=L&doc.norm=all
# * https://www.daec.de/media/files/2022/Fachbereiche/Umwelt/Leitfaden_Luftfahrthindernisse_14_03_2022.pdf
# * https://www.fsco.de/images/Dokumente/Studie_DLR.pdf
# * https://www.dhv.de/fileadmin/user_upload/aktuell_zu_halten/Gelaende/DHV_info_199_windkraft.pdf
# * http://www.pontepress.de/pdf/u12_201706.pdf

# %%
import zipfile
import os

def create_kmz(kml_filename, dae_filenames, output_filename):
    with zipfile.ZipFile(output_filename, 'w') as kmz:
        kmz.write(kml_filename)

        for dae in dae_filenames:
            kmz.write(dae, os.path.join("models", os.path.basename(dae)))

#if __name__ == "__main__":

# Listet alle .dae-Dateien im "model"-Verzeichnis auf

dae_files = [os.path.join("models", f) for f in os.listdir("models") if f.endswith('.dae')]

output_file = "wka-boesingen.kmz"
create_kmz(kml_file, dae_files, output_file)

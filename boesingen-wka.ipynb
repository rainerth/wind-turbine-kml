# %%
import sys
import os

os.chdir('/home/rainerth/notebooks/wind-turbine-kml/')
# os.chdir(os.path.dirname(__file__))

#print(os.listdir('.'))
print(sys.path)

# sys.path.append('./collada_wt')

import collada_wt
import simplekml
# https://simplekml.readthedocs.io/en/latest/index.html

print(collada_wt.__file__)
# Out:
# ['/home/rainerth/notebooks', '/home/rainerth/anaconda3/lib/python38.zip', '/home/rainerth/anaconda3/lib/python3.8', '/home/rainerth/anaconda3/lib/python3.8/lib-dynload', '', '/home/rainerth/.local/lib/python3.8/site-packages', '/home/rainerth/anaconda3/lib/python3.8/site-packages', '/home/rainerth/anaconda3/lib/python3.8/site-packages/locket-0.2.1-py3.8.egg']
# /home/rainerth/notebooks/wind-turbine-kml/collada_wt/__init__.py

# %%
# create turbine
# https://www.wind-turbine-models.com/turbines/2425-vestas-v172-7.2-enventus
# https://www.koordinaten-umrechner.de/decimal/48.237694,8.524661?karte=OpenStreetMap&zoom=16

daeurl = "models"

collada_wt1 = collada_wt.create_turbine(tower_height=199,
                    tower_bot_diameter = 6,
                    tower_top_diameter = 5,
                    nacelle_height = 3,
                    nacelle_length = 20,
                    nacelle_overhang = 8,
                    rotor_diameter = 172,
                    blade_root_length = 3.5,
                    blade_root_diameter = 3,
                    blade_chord=4,
                    blade_tip_size=0.5,
                    blade_twist=30,
                )

collada_wt1.write(daeurl + '/vestas-v172.dae')

collada_wt2 = collada_wt.create_turbine(tower_height=95,
                    tower_bot_diameter = 5,
                    tower_top_diameter = 4,
                    nacelle_height = 3,
                    nacelle_length = 10,
                    nacelle_overhang = 4,
                    rotor_diameter = 70,
                    blade_root_length = 2.5,
                    blade_root_diameter = 2,
                    blade_chord=4,
                    blade_tip_size=0.5,
                    blade_twist=30,
                )

collada_wt2.write(daeurl + '/WEA-2003.dae')


# WEA geplant
collada_zone = collada_wt.create_zone(
                    zone_height=199+172/2+100,
                    zone_diameter = 150*2+172,
                )
collada_zone.write(daeurl + '/WEA-safety-zone.dae')


# WEA 2003
collada_zone = collada_wt.create_zone(
                    zone_height=99+60/2+100,
                    zone_diameter = 150*2+60,
                )
collada_zone.write(daeurl + '/WEA-safety-zone-2003.dae')


# Testturm RW
collada_zone = collada_wt.create_zone(
                    zone_height=246,
                    zone_diameter = 24,
                )
collada_zone.write(daeurl + '/testturm.dae')

# %%
# create kml for Google Earth
# https://www.schwarzwaelder-bote.de/inhalt.windenergieanlagen-in-boesingen-drei-plus-maximal-fuenf-im-gespraech.8840b7d3-7346-4f63-8c82-27f76a697bdd.html
#
kml = simplekml.Kml()
daeurl = "models"


# Bösingen badenova
folder = kml.newfolder(name='badenova')
folder_safety = folder.newfolder(name='Safety')

model = folder.newmodel(name='WEA-b1')
# model.description = "WEA Vestas V172"
model.link.href = daeurl + '/vestas-v172.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.25170660125827
model.location.longitude = 8.531436993300845
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = folder_safety.newmodel(name='WEA-b1-safety')
model.link.href = daeurl + '/WEA-safety-zone.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.25170660125827
model.location.longitude = 8.531436993300845
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1
model.visibility = 0


model = folder.newmodel(name='WEA-b2')
# model.description = "WEA Vestas V172"
model.link.href = daeurl + '/vestas-v172.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.255288371442475
model.location.longitude = 8.536407791352117
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = folder_safety.newmodel(name='WEA-b2-safety')
model.link.href = daeurl + '/WEA-safety-zone.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.255288371442475
model.location.longitude = 8.536407791352117
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1
model.visibility = 0


model = folder.newmodel(name='WEA-b3')
# model.description = "WEA Vestas V172"
model.link.href = daeurl + '/vestas-v172.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.25229602372512
model.location.longitude = 8.543829941867028
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = folder_safety.newmodel(name='WEA-b3-safety')
model.link.href = daeurl + '/WEA-safety-zone.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.25229602372512
model.location.longitude = 8.543829941867028
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1
model.visibility = 0


model = folder.newmodel(name='WEA-b4')
# model.description = "WEA Vestas V172"
model.link.href = daeurl + '/vestas-v172.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.25587775262197
model.location.longitude = 8.55077544051401
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = folder_safety.newmodel(name='WEA-b4-safety')
model.link.href = daeurl + '/WEA-safety-zone.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.25587775262197
model.location.longitude = 8.55077544051401
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1
model.visibility = 0


model = folder.newmodel(name='WEA-b5')
# model.description = "WEA Vestas V172"
model.link.href = daeurl + '/vestas-v172.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.2668480695609
model.location.longitude = 8.559627546632713
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = folder_safety.newmodel(name='WEA-b5-safety')
model.link.href = daeurl + '/WEA-safety-zone.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.2668480695609
model.location.longitude = 8.559627546632713
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1
model.visibility = 0



# Bösingen iTerra
folder = kml.newfolder(name='iTerra')
folder_safety = folder.newfolder(name='Safety')

model = folder.newmodel(name='WEA-iT01')
# model.description = "WEA Vestas V172"
model.link.href = daeurl + '/vestas-v172.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.25413391819091
model.location.longitude = 8.535100799283962
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = folder_safety.newmodel(name='WEA-iT01-safety')
model.link.href = daeurl + '/WEA-safety-zone.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.25413391819091
model.location.longitude = 8.535100799283962
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1
model.visibility = 0


model = folder.newmodel(name='WEA-iT02')
# model.description = "WEA Vestas V172"
model.link.href = daeurl + '/vestas-v172.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.252190833616346
model.location.longitude = 8.544027190435052
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = folder_safety.newmodel(name='WEA-iT02-safety')
model.link.href = daeurl + '/WEA-safety-zone.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.252190833616346
model.location.longitude = 8.544027190435052
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1
model.visibility = 0


model = folder.newmodel(name='WEA-iT03')
# model.description = "WEA Vestas V172"
model.link.href = daeurl + '/vestas-v172.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.2535624303927
model.location.longitude = 8.515617233983022
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = folder_safety.newmodel(name='WEA-iT03-safety')
model.link.href = daeurl + '/WEA-safety-zone.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.2535624303927
model.location.longitude = 8.515617233983022
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1
model.visibility = 0


model = folder.newmodel(name='WEA-iT04')
# model.description = "WEA Vestas V172"
model.link.href = daeurl + '/vestas-v172.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.250990656256285
model.location.longitude = 8.523341995556082
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = folder_safety.newmodel(name='WEA-iT04-safety')
model.link.href = daeurl + '/WEA-safety-zone.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.250990656256285
model.location.longitude = 8.523341995556082
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1
model.visibility = 0


model = folder.newmodel(name='WEA-iT05')
# model.description = "WEA Vestas V172"
model.link.href = daeurl + '/vestas-v172.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.24796151194575
model.location.longitude = 8.533040862864478
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = folder_safety.newmodel(name='WEA-iT05-safety')
model.link.href = daeurl + '/WEA-safety-zone.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.24796151194575
model.location.longitude = 8.533040862864478
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1
model.visibility = 0


model = folder.newmodel(name='WEA-iT06')
# model.description = "WEA Vestas V172"
model.link.href = daeurl + '/vestas-v172.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.24813297773512
model.location.longitude = 8.513814789615974
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = folder_safety.newmodel(name='WEA-iT06-safety')
model.link.href = daeurl + '/WEA-safety-zone.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.24813297773512
model.location.longitude = 8.513814789615974
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1
model.visibility = 0


model = folder.newmodel(name='WEA-iT07')
# model.description = "WEA Vestas V172"
model.link.href = daeurl + '/vestas-v172.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.24253146460605
model.location.longitude = 8.515831810693385
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = folder_safety.newmodel(name='WEA-iT07-safety')
model.link.href = daeurl + '/WEA-safety-zone.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.24253146460605
model.location.longitude = 8.515831810693385
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1
model.visibility = 0


model = folder.newmodel(name='WEA-iT08')
# model.description = "WEA Vestas V172"
model.link.href = daeurl + '/vestas-v172.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.24356035994735
model.location.longitude = 8.526903968948103
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = folder_safety.newmodel(name='WEA-iT08-safety')
model.link.href = daeurl + '/WEA-safety-zone.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.24356035994735
model.location.longitude = 8.526903968948103
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1
model.visibility = 0


model = folder.newmodel(name='WEA-iT09')
# model.description = "WEA Vestas V172"
model.link.href = daeurl + '/vestas-v172.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.239378087990616
model.location.longitude = 8.530826802257371
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = folder_safety.newmodel(name='WEA-iT09-safety')
model.link.href = daeurl + '/WEA-safety-zone.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.239378087990616
model.location.longitude = 8.530826802257371
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1
model.visibility = 0


model = folder.newmodel(name='WEA-iT10')
# model.description = "WEA Vestas V172"
model.link.href = daeurl + '/vestas-v172.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.26572434326006
model.location.longitude = 8.56485867028379
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = folder_safety.newmodel(name='WEA-iT10-safety')
model.link.href = daeurl + '/WEA-safety-zone.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.26572434326006
model.location.longitude = 8.56485867028379
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1
model.visibility = 0




# Dunningen
folder = kml.newfolder(name='Dunningen')
folder_safety = folder.newfolder(name='Safety')

model = folder.newmodel(name='WEA-D1',)
model.link.href = daeurl + '/WEA-2003.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.219839
model.location.longitude = 8.532344
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = folder_safety.newmodel(name='WEA-D1-safety',)
model.link.href = daeurl + '/WEA-safety-zone-2003.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.219839
model.location.longitude = 8.532344
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1
model.visibility = 0


model = folder.newmodel(name='WEA-D2',)
model.link.href = daeurl + '/WEA-2003.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.221684
model.location.longitude = 8.527035
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = folder_safety.newmodel(name='WEA-D2-safety',)
model.link.href = daeurl + '/WEA-safety-zone-2003.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.221684
model.location.longitude = 8.527035
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1
model.visibility = 0


model = folder.newmodel(name='WEA-D3',)
model.link.href = daeurl + '/WEA-2003.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.221112
model.location.longitude = 8.522828
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = folder_safety.newmodel(name='WEA-D3-safety',)
model.link.href = daeurl + '/WEA-safety-zone-2003.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.221112
model.location.longitude = 8.522828
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1
model.visibility = 0


# Herrenzimmern
folder = kml.newfolder(name='Herrenzimmern')
folder_safety = folder.newfolder(name='Safety')

model = folder.newmodel(name='WEA-H1',)
model.link.href = daeurl + '/vestas-v172.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.212488
model.location.longitude = 8.575546
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = folder_safety.newmodel(name='WEA-H1-safety',)
model.link.href = daeurl + '/WEA-safety-zone.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.212488
model.location.longitude = 8.575546
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1
model.visibility = 0

model = folder.newmodel(name='WEA-H2',)
model.link.href = daeurl + '/vestas-v172.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.208998
model.location.longitude = 8.555794
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = folder_safety.newmodel(name='WEA-H2-safety',)
model.link.href = daeurl + '/WEA-safety-zone.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.208998
model.location.longitude = 8.555794
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1
model.visibility = 0

model = folder.newmodel(name='WEA-H3',)
model.link.href = daeurl + '/vestas-v172.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.209003
model.location.longitude = 8.541822
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = folder_safety.newmodel(name='WEA-H3-safety',)
model.link.href = daeurl + '/WEA-safety-zone.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.209003
model.location.longitude = 8.541822
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1
model.visibility = 0


folder = kml.newfolder(name='Testturm')

model = folder.newmodel(name='Testturm',)
model.link.href = daeurl + '/testturm.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.179222
model.location.longitude = 8.625056
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

model = folder.newmodel(name='Testturm-Vergleich',)
# model.description = "Thyssen Testturm zum Vergleich, 246m"
model.link.href = daeurl + '/testturm.dae'
model.altitudemode = 'clampToGround'
model.location.latitude = 48.24470102174442
model.location.longitude = 8.544851338726877
model.scale.x = 1
model.scale.y = 1
model.scale.z = 1

# %%
style = simplekml.Style()
style.labelstyle.color = simplekml.Color.lightgray  # Make the text red
style.labelstyle.scale = 0.8  # Make the text twice as big
style.iconstyle.icon.href = 'http://maps.google.com/mapfiles/kml/shapes/placemark_circle.png'
style.iconstyle.color = simplekml.Color.darkgray

style_badenova = simplekml.Style()
style_badenova.labelstyle.color = simplekml.Color.lightgray  # Make the text blue
style_badenova.labelstyle.scale = 0.8  # Make the text twice as big
style_badenova.iconstyle.icon.href = 'http://maps.google.com/mapfiles/kml/shapes/placemark_circle.png'
style_badenova.iconstyle.color = simplekml.Color.lightblue

style_iterra = simplekml.Style()
style_iterra.labelstyle.color = simplekml.Color.lightgray  # Make the text red
style_iterra.labelstyle.scale = 0.8  # Make the text twice as big
style_iterra.iconstyle.icon.href = 'http://maps.google.com/mapfiles/kml/shapes/placemark_circle.png'
style_iterra.iconstyle.color = simplekml.Color.red

folder = kml.newfolder(name='Standorte')

location = folder.newpoint(name="WEA-b1", coords=[(8.531436993300845, 48.25170660125827)])
location.style=style_badenova

location = folder.newpoint(name="WEA-b2", coords=[(8.536407791352117, 48.255288371442475)])
location.style=style_badenova

location = folder.newpoint(name="WEA-b3", coords=[(8.543829941867028, 48.25229602372512)])
location.style=style_badenova

location = folder.newpoint(name="WEA-b4", coords=[(8.55077544051401, 48.25587775262197)])
location.style=style_badenova

location = folder.newpoint(name="WEA-b5", coords=[(8.559627546632713, 48.2668480695609)])
location.style=style_badenova

location = folder.newpoint(name="WEA-iT01", coords=[(8.535100799283962, 48.25413391819091)])
location.style=style_iterra

location = folder.newpoint(name="WEA-iT03", coords=[(8.515617233983022, 48.2535624303927)])
location.style=style_iterra

location = folder.newpoint(name="WEA-iT02", coords=[(8.544027190435052, 48.252190833616346)])
location.style=style_iterra

location = folder.newpoint(name="WEA-iT04", coords=[(8.523341995556082, 48.250990656256285)])
location.style=style_iterra

location = folder.newpoint(name="WEA-iT05", coords=[(8.533040862864478, 48.24796151194575)])
location.style=style_iterra

location = folder.newpoint(name="WEA-iT06", coords=[(8.513814789615974, 48.24813297773512)])
location.style=style_iterra

location = folder.newpoint(name="WEA-iT07", coords=[(8.515831810693385, 48.24253146460605)])
location.style=style_iterra

location = folder.newpoint(name="WEA-iT08", coords=[(8.526903968948103, 48.24356035994735)])
location.style=style_iterra

location = folder.newpoint(name="WEA-iT09", coords=[(8.530826802257371, 48.239378087990616)])
location.style=style_iterra

location = folder.newpoint(name="WEA-iT10", coords=[(8.56485867028379, 48.26572434326006)])
location.style=style_iterra

location = folder.newpoint(name="WEA-D1", coords=[(8.532344, 48.219839)])
location.style=style

location = folder.newpoint(name="WEA-D2", coords=[(8.527035, 48.221684)])
location.style=style

location = folder.newpoint(name="WEA-D3", coords=[(8.522828, 48.221112)])
location.style=style

location = folder.newpoint(name="WEA-H1", coords=[(8.575546, 48.212488)])
location.style=style

location = folder.newpoint(name="WEA-H2", coords=[(8.555794, 48.208998)])
location.style=style

location = folder.newpoint(name="WEA-H3", coords=[(8.541822, 48.209003)])
location.style=style

# %%
kml_file = './WEA-boesingen.kml'
kml.save(kml_file)

# %%
import zipfile

def create_kmz(kml_filename, dae_filenames, output_filename):
    with zipfile.ZipFile(output_filename, 'w') as kmz:
        kmz.write(kml_filename)

        for dae in dae_filenames:
            kmz.write(dae, os.path.join("models", os.path.basename(dae)))

#if __name__ == "__main__":

# Listet alle .dae-Dateien im "model"-Verzeichnis auf

dae_files = [os.path.join("models", f) for f in os.listdir("models") if f.endswith('.dae')]
kml_file = "WEA-boesingen.kml"  # Ersetzen Sie dies durch den Pfad zu Ihrer KML-Datei
output_file = "WEA-boesingen.kmz"
create_kmz(kml_file, dae_files, output_file)

# %% [markdown]
# ## Quellen
#
# * https://www.landesrecht-bw.de/jportal/?quelle=jlink&docid=JURE060017391&psml=bsbawueprod.psml&max=true&doc.part=L&doc.norm=all
# * https://www.daec.de/media/files/2022/Fachbereiche/Umwelt/Leitfaden_Luftfahrthindernisse_14_03_2022.pdf
# * https://www.fsco.de/images/Dokumente/Studie_DLR.pdf
# * https://www.dhv.de/fileadmin/user_upload/aktuell_zu_halten/Gelaende/DHV_info_199_windkraft.pdf
# * http://www.pontepress.de/pdf/u12_201706.pdf
